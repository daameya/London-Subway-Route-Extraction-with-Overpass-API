# %%
import requests
import folium

def extract_osm_geodata(query):
    """
    Extracts geodata from OpenStreetMap using the Overpass API.
    Parameters:
    query (str): The Overpass API query string to execute.
    Returns:
    dict: GeoJSON data retrieved by the query.
    """
    # Define the Overpass API URL
    overpass_url = "https://lz4.overpass-api.de/api/interpreter"
    
    # Define the parameters for the GET request
    params = {'data': query}
    
    # Send a GET request to the Overpass API with the query
    response = requests.get(overpass_url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        response.raise_for_status()

# %%
# Query to extract subway stations in Paris
query = """
[out:json];
area[name="Paris"]->.searchArea;
relation["route"~"subway"](area.searchArea);
out meta;
>;
out body;
"""
subway_paris_data = extract_osm_geodata(query)

# %%
def extract_route_elements(osm_data):
    """
    Extracts route elements from the OpenStreetMap data response.
    Parameters:
    osm_data (dict): The JSON response data from the Overpass API.
    Returns:
    list: A list of route elements containing 'tags' with 'route' information.
    """
    route_elements = [element for element in osm_data['elements'] if 'tags' in element and 'route' in element['tags']]
    return route_elements

# Call the function to extract route elements from the OpenStreetMap data for London's subway
route_elements =  extract_route_elements(subway_paris_data)

# Visualize the route of the list
route_elements[0]
# Out:
# {'type': 'relation',
#  'id': 123564,
#  'timestamp': '2024-05-22T03:44:23Z',
#  'version': 103,
#  'changeset': 151654412,
#  'user': 'OrdinaryScarlett',
#  'uid': 9159276,
#  'members': [{'type': 'node', 'ref': 6935745351, 'role': 'stop_entry_only'},
#   {'type': 'way', 'ref': 740818758, 'role': 'platform_entry_only'},
#   {'type': 'node', 'ref': 6935824089, 'role': 'stop'},
#   {'type': 'way', 'ref': 740808707, 'role': 'platform'},
#   {'type': 'node', 'ref': 6935745186, 'role': 'stop'},
#   {'type': 'way', 'ref': 740808700, 'role': 'platform'},
#   {'type': 'node', 'ref': 6935842896, 'role': 'stop'},
#   {'type': 'way', 'ref': 230505258, 'role': 'platform'},
#   {'type': 'node', 'ref': 300870184, 'role': 'stop'},
#   {'type': 'node', 'ref': 300870186, 'role': 'stop'},
#   {'type': 'node', 'ref': 300876896, 'role': 'stop'},
#   {'type': 'node', 'ref': 300877457, 'role': 'stop'},
#   {'type': 'node', 'ref': 264482296, 'role': 'stop'},
#   {'type': 'node', 'ref': 264491320, 'role': 'stop'},
#   {'type': 'node', 'ref': 264482297, 'role': 'stop'},
#   {'type': 'node', 'ref': 264482226, 'role': 'stop'},
#   {'type': 'node', 'ref': 4317625018, 'role': 'stop'},
#   {'type': 'node', 'ref': 264481854, 'role': 'stop'},
#   {'type': 'node', 'ref': 5226630375, 'role': 'stop'},
#   {'type': 'node', 'ref': 264481019, 'role': 'stop'},
#   {'type': 'node', 'ref': 264480784, 'role': 'stop'},
#   {'type': 'node', 'ref': 1584432760, 'role': 'stop'},
#   {'type': 'node', 'ref': 264479775, 'role': 'stop'},
#   {'type': 'node', 'ref': 264479724, 'role': 'stop'},
#   {'type': 'node', 'ref': 264476971, 'role': 'stop'},
#   {'type': 'node', 'ref': 7068210648, 'role': 'stop'},
#   {'type': 'node', 'ref': 11563663300, 'role': 'stop'},
#   {'type': 'node', 'ref': 11563663298, 'role': 'stop'},
#   {'type': 'node', 'ref': 11563663317, 'role': 'stop'},
#   {'type': 'node', 'ref': 8515111502, 'role': 'stop'},
#   {'type': 'way', 'ref': 916789679, 'role': 'platform'},
#   {'type': 'node', 'ref': 4693317862, 'role': 'stop'},
#   {'type': 'way', 'ref': 475595538, 'role': 'platform'},
#   {'type': 'node', 'ref': 5226630383, 'role': 'stop'},
#   {'type': 'way', 'ref': 678701627, 'role': 'platform'},
#   {'type': 'node', 'ref': 1489806669, 'role': 'stop'},
#   {'type': 'node', 'ref': 1489806675, 'role': 'stop'},
#   {'type': 'node', 'ref': 264473011, 'role': 'stop'},
#   {'type': 'node', 'ref': 264469541, 'role': 'stop'},
#   {'type': 'node', 'ref': 5226630372, 'role': 'stop'},
#   {'type': 'node', 'ref': 264469160, 'role': 'stop'},
#   {'type': 'node', 'ref': 260231833, 'role': 'stop'},
#   {'type': 'node', 'ref': 260231832, 'role': 'stop'},
#   {'type': 'node', 'ref': 260231831, 'role': 'stop'},
#   {'type': 'node', 'ref': 260231828, 'role': 'stop'},
#   {'type': 'way', 'ref': 593477259, 'role': ''},
#   {'type': 'way', 'ref': 1021373981, 'role': ''},
#   {'type': 'way', 'ref': 1021373980, 'role': ''},
#   {'type': 'way', 'ref': 594355563, 'role': ''},
#   {'type': 'way', 'ref': 593477251, 'role': ''},
#   {'type': 'way', 'ref': 593477246, 'role': ''},
#   {'type': 'way', 'ref': 593477245, 'role': ''},
#   {'type': 'way', 'ref': 593477244, 'role': ''},
#   {'type': 'way', 'ref': 740808701, 'role': ''},
#   {'type': 'way', 'ref': 593477239, 'role': ''},
#   {'type': 'way', 'ref': 594357090, 'role': ''},
#   {'type': 'way', 'ref': 593477238, 'role': ''},
#   {'type': 'way', 'ref': 593477237, 'role': ''},
#   {'type': 'way', 'ref': 594357822, 'role': ''},
#   {'type': 'way', 'ref': 594357812, 'role': ''},
#   {'type': 'way', 'ref': 594357817, 'role': ''},
#   {'type': 'way', 'ref': 412994013, 'role': ''},
#   {'type': 'way', 'ref': 412994011, 'role': ''},
#   {'type': 'way', 'ref': 27256005, 'role': ''},
#   {'type': 'way', 'ref': 27256031, 'role': ''},
#   {'type': 'way', 'ref': 412987854, 'role': ''},
#   {'type': 'way', 'ref': 27408100, 'role': ''},
#   {'type': 'way', 'ref': 27408185, 'role': ''},
#   {'type': 'way', 'ref': 756780045, 'role': ''},
#   {'type': 'way', 'ref': 1244001805, 'role': ''},
#   {'type': 'way', 'ref': 1244001806, 'role': ''},
#   {'type': 'way', 'ref': 916789598, 'role': ''},
#   {'type': 'way', 'ref': 916789596, 'role': ''},
#   {'type': 'way', 'ref': 475598700, 'role': ''},
#   {'type': 'way', 'ref': 313420254, 'role': ''},
#   {'type': 'way', 'ref': 390827576, 'role': ''}],
#  'tags': {'colour': '#d282be',
#   'from': 'Pointe du Lac',
#   'line': 'subway',
#   'name': 'Ligne 8 : Pointe du Lac → Balard',
#   'network': 'Métro de Paris',
#   'network:wikidata': 'Q50716',
#   'network:wikipedia': 'fr:Métro de Paris',
#   'operator': 'RATP',
#   'operator:wikidata': 'Q643290',
#   'operator:wikipedia': 'fr:Régie autonome des transports parisiens',
#   'public_transport:version': '2',
#   'ref': '8',
#   'ref:FR:RATP': '1001100080001',
#   'route': 'subway',
#   'short_name': 'M8',
#   'to': 'Balard',
#   'twitter': 'Ligne8_RATP',
#   'type': 'route',
#   'wheelchair': 'no',
#   'wikidata': 'Q50751',
#   'wikipedia': 'fr:Ligne 8 du métro de Paris'}}

# %%
def extract_node_elements(osm_data):
    """
    Extracts node elements from the OpenStreetMap data response.
    Parameters:
    osm_data (dict): The JSON response data from the Overpass API.
    Returns:
    dict: A dictionary where the keys are node IDs and the values are the corresponding node elements.
    """
    node_elements = {element['id']: element for element in osm_data['elements'] if element['type'] == 'node'}
    return node_elements

# Call the function to extract node elements from the OpenStreetMap data for Hamburg's subway
node_elements = extract_node_elements(subway_paris_data)

# Visualize the node_elements list
node_elements
# Out:
# {361068: {'type': 'node', 'id': 361068, 'lat': 48.8560699, 'lon': 2.3507047},
#  361106: {'type': 'node', 'id': 361106, 'lat': 48.8729396, 'lon': 2.3332569},
#  12388528: {'type': 'node',
#   'id': 12388528,
#   'lat': 48.8108097,
#   'lon': 2.3015874,
#   'tags': {'name': 'Châtillon-Montrouge',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  12388529: {'type': 'node',
#   'id': 12388529,
#   'lat': 48.8118955,
#   'lon': 2.3006239,
#   'tags': {'railway': 'switch'}},
#  12388531: {'type': 'node',
#   'id': 12388531,
#   'lat': 48.8128443,
#   'lon': 2.2995757},
#  12388535: {'type': 'node',
#   'id': 12388535,
#   'lat': 48.8161198,
#   'lon': 2.2963099},
#  12388536: {'type': 'node',
#   'id': 12388536,
#   'lat': 48.8167765,
#   'lon': 2.2958503},
#  12388537: {'type': 'node',
#   'id': 12388537,
#   'lat': 48.8171778,
#   'lon': 2.2956324},
#  12388538: {'type': 'node',
#   'id': 12388538,
#   'lat': 48.8178419,
#   'lon': 2.2953913},
#  12388539: {'type': 'node',
#   'id': 12388539,
#   'lat': 48.8187322,
#   'lon': 2.2952793},
#  12388540: {'type': 'node',
#   'id': 12388540,
#   'lat': 48.8193776,
#   'lon': 2.2953158},
#  12388541: {'type': 'node',
#   'id': 12388541,
#   'lat': 48.819794,
#   'lon': 2.2954559},
#  12388542: {'type': 'node',
#   'id': 12388542,
#   'lat': 48.8202589,
#   'lon': 2.2957085},
#  12388543: {'type': 'node',
#   'id': 12388543,
#   'lat': 48.820658,
#   'lon': 2.2960728},
#  19405766: {'type': 'node',
#   'id': 19405766,
#   'lat': 48.8834749,
#   'lon': 2.3472499},
#  21378249: {'type': 'node',
#   'id': 21378249,
#   'lat': 48.8581182,
#   'lon': 2.3111649},
#  24958711: {'type': 'node',
#   'id': 24958711,
#   'lat': 48.8524605,
#   'lon': 2.3319308,
#   'tags': {'highway': 'traffic_signals'}},
#  25554264: {'type': 'node',
#   'id': 25554264,
#   'lat': 48.8627294,
#   'lon': 2.3352505},
#  26721276: {'type': 'node',
#   'id': 26721276,
#   'lat': 48.8895077,
#   'lon': 2.3152622,
#   'tags': {'STIF:zone': '1',
#    'name': 'Pont Cardinet',
#    'network': 'RATP',
#    'official_name': 'PONT CARDINET',
#    'opening_date': '2020-12-14',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:STIF': '411351',
#    'source': 'survey',
#    'subway': 'yes',
#    'uic_ref': '8738111',
#    'wheelchair': 'yes'}},
#  27234873: {'type': 'node',
#   'id': 27234873,
#   'lat': 48.8806708,
#   'lon': 2.3182981},
#  27286712: {'type': 'node',
#   'id': 27286712,
#   'lat': 48.8758928,
#   'lon': 2.2965695},
#  27332859: {'type': 'node',
#   'id': 27332859,
#   'lat': 48.8858521,
#   'lon': 2.2569949},
#  27362240: {'type': 'node',
#   'id': 27362240,
#   'lat': 48.87515,
#   'lon': 2.2906706,
#   'tags': {'STIF:zone': '1',
#    'layer': '-2',
#    'level': '-2',
#    'name': 'Argentine',
#    'name:ru': 'Аржантин',
#    'network': 'Métro de Paris;RATP',
#    'old_name': 'Obligado',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref': '2',
#    'source': 'STIF - 12/2016',
#    'start_date': '1900-09-01',
#    'subway': 'yes',
#    'type:RATP': 'metro'}},
#  27362249: {'type': 'node',
#   'id': 27362249,
#   'lat': 48.8720617,
#   'lon': 2.3004148,
#   'tags': {'STIF:zone': '1',
#    'name': 'George\xa0V',
#    'name:ru': 'Георг V',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  27362251: {'type': 'node',
#   'id': 27362251,
#   'lat': 48.8690339,
#   'lon': 2.3099266,
#   'tags': {'STIF:zone': '1',
#    'name': 'Franklin D. Roosevelt',
#    'name:ru': 'Франклин Д. Рузвельт',
#    'old_name': 'Marbeuf Rond Point des Champs-Élysées',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75108S169G',
#    'ref:FR:RATP': '1924',
#    'ref:FR:STIF': '21931',
#    'source': 'survey',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1445234',
#    'wikipedia': 'fr:Franklin D. Roosevelt (métro de Paris)'}},
#  27362252: {'type': 'node',
#   'id': 27362252,
#   'lat': 48.8660736,
#   'lon': 2.3201129},
#  27362253: {'type': 'node',
#   'id': 27362253,
#   'lat': 48.8661144,
#   'lon': 2.3203822},
#  27362254: {'type': 'node',
#   'id': 27362254,
#   'lat': 48.8661992,
#   'lon': 2.3206677},
#  27362257: {'type': 'node',
#   'id': 27362257,
#   'lat': 48.8663718,
#   'lon': 2.3222271,
#   'tags': {'STIF:zone': '1',
#    'name': 'Concorde',
#    'name:de': 'Concorde',
#    'name:es': 'Concorde',
#    'name:it': 'Concorde',
#    'name:pt': 'Concorde',
#    'name:ru': 'Конкорд',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:RATP': '1885',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q970075',
#    'wikipedia': 'fr:Concorde (métro de Paris)'}},
#  27362259: {'type': 'node',
#   'id': 27362259,
#   'lat': 48.8623763,
#   'lon': 2.3363706,
#   'tags': {'railway': 'signal',
#    'railway:signal:direction': 'forward',
#    'railway:signal:main': 'yes',
#    'railway:signal:main:form': 'light',
#    'railway:signal:speed_limit': 'yes',
#    'railway:signal:speed_limit:speed': '50',
#    'wikidata': 'Q1467113'}},
#  27362260: {'type': 'node',
#   'id': 27362260,
#   'lat': 48.8608027,
#   'lon': 2.3411235,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2023-03-13',
#    'name': 'Louvre - Rivoli',
#    'name:ru': 'Лувр — Риволи',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'source': 'STIF - 12/2016',
#    'subway': 'yes',
#    'wheelchair': 'no'}},
#  27371872: {'type': 'node',
#   'id': 27371872,
#   'lat': 48.8522391,
#   'lon': 2.3681596},
#  27371874: {'type': 'node',
#   'id': 27371874,
#   'lat': 48.8520622,
#   'lon': 2.3683671},
#  27371876: {'type': 'node',
#   'id': 27371876,
#   'lat': 48.8519877,
#   'lon': 2.3686653,
#   'tags': {'name': 'Bastille',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  27371892: {'type': 'node',
#   'id': 27371892,
#   'lat': 48.8473535,
#   'lon': 2.3868105},
#  27371900: {'type': 'node',
#   'id': 27371900,
#   'lat': 48.8473335,
#   'lon': 2.4080861,
#   'tags': {'name': 'Porte de Vincennes',
#    'public_transport': 'stop_position',
#    'subway': 'yes',
#    'wheelchair': 'no'}},
#  29588070: {'type': 'node',
#   'id': 29588070,
#   'lat': 48.8336468,
#   'lon': 2.2435931,
#   'tags': {'STIF:zone': '1',
#    'name': 'Marcel Sembat',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:RATP': '1829',
#    'ref:FR:STIF': '21940',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q613123',
#    'wikipedia': 'fr:Marcel Sembat (métro de Paris)'}},
#  32561341: {'type': 'node',
#   'id': 32561341,
#   'lat': 48.871388,
#   'lon': 2.3100809,
#   'tags': {'fixme:asl': "ajout d'un éventuel Sas cyclable à côté du feu : cycleway=asl",
#    'fixme:bicycle:give_way': "ajout d'un éventuel Cédez-le-passage cycliste au feu : type=restriction ; restriction:bicycle=give_way",
#    'highway': 'traffic_signals'}},
#  34817055: {'type': 'node',
#   'id': 34817055,
#   'lat': 48.8702255,
#   'lon': 2.2828083,
#   'tags': {'highway': 'traffic_signals'}},
#  34909167: {'type': 'node',
#   'id': 34909167,
#   'lat': 48.850949,
#   'lon': 2.2923333},
#  34909168: {'type': 'node',
#   'id': 34909168,
#   'lat': 48.8507993,
#   'lon': 2.2925594},
#  34909169: {'type': 'node',
#   'id': 34909169,
#   'lat': 48.8507132,
#   'lon': 2.2927546},
#  34909180: {'type': 'node',
#   'id': 34909180,
#   'lat': 48.8454279,
#   'lon': 2.3102995},
#  34909181: {'type': 'node',
#   'id': 34909181,
#   'lat': 48.8453481,
#   'lon': 2.3105413},
#  34909182: {'type': 'node',
#   'id': 34909182,
#   'lat': 48.8452667,
#   'lon': 2.3107027},
#  34909183: {'type': 'node',
#   'id': 34909183,
#   'lat': 48.8451183,
#   'lon': 2.3108731},
#  94150523: {'type': 'node',
#   'id': 94150523,
#   'lat': 48.8638063,
#   'lon': 2.3822716,
#   'tags': {'crossing': 'unmarked',
#    'crossing:markings': 'no',
#    'highway': 'crossing'}},
#  134305192: {'type': 'node',
#   'id': 134305192,
#   'lat': 48.8324292,
#   'lon': 2.2879898,
#   'tags': {'STIF:zone': '1',
#    'name': 'Porte de Versailles',
#    'name:ru': 'Порт-де-Версай',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75115S448G',
#    'ref:FR:RATP': '1732;1606',
#    'source': 'STIF - 12/2016',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no'}},
#  134305193: {'type': 'node',
#   'id': 134305193,
#   'lat': 48.8343331,
#   'lon': 2.2908632},
#  134305194: {'type': 'node',
#   'id': 134305194,
#   'lat': 48.83548,
#   'lon': 2.2927686},
#  141561174: {'type': 'node',
#   'id': 141561174,
#   'lat': 48.8461462,
#   'lon': 2.2780662},
#  147024524: {'type': 'node',
#   'id': 147024524,
#   'lat': 48.8663645,
#   'lon': 2.3212134},
#  151357502: {'type': 'node',
#   'id': 151357502,
#   'lat': 48.8659968,
#   'lon': 2.3707083},
#  185858362: {'type': 'node',
#   'id': 185858362,
#   'lat': 48.8576538,
#   'lon': 2.2856493,
#   'tags': {'name': 'Passy',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  202404446: {'type': 'node',
#   'id': 202404446,
#   'lat': 48.8876883,
#   'lon': 2.2511453},
#  206155796: {'type': 'node',
#   'id': 206155796,
#   'lat': 48.850292,
#   'lon': 2.3985875},
#  235367830: {'type': 'node',
#   'id': 235367830,
#   'lat': 48.8296063,
#   'lon': 2.3490368},
#  235367831: {'type': 'node',
#   'id': 235367831,
#   'lat': 48.8295366,
#   'lon': 2.3494968},
#  235367832: {'type': 'node',
#   'id': 235367832,
#   'lat': 48.8295578,
#   'lon': 2.349699},
#  235367834: {'type': 'node',
#   'id': 235367834,
#   'lat': 48.8299591,
#   'lon': 2.3510212},
#  235367835: {'type': 'node',
#   'id': 235367835,
#   'lat': 48.8303596,
#   'lon': 2.3522844},
#  235370505: {'type': 'node',
#   'id': 235370505,
#   'lat': 48.8297902,
#   'lon': 2.350489,
#   'tags': {'name': 'Corvisart',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75113P005M;75113P006N',
#    'subway': 'yes',
#    'train': 'yes'}},
#  235373047: {'type': 'node',
#   'id': 235373047,
#   'lat': 48.8353355,
#   'lon': 2.3691865},
#  235373050: {'type': 'node',
#   'id': 235373050,
#   'lat': 48.8355955,
#   'lon': 2.3698727},
#  235373053: {'type': 'node',
#   'id': 235373053,
#   'lat': 48.8359944,
#   'lon': 2.3707968},
#  241928757: {'type': 'node',
#   'id': 241928757,
#   'lat': 48.8445799,
#   'lon': 2.438912,
#   'tags': {'name': 'Château de Vincennes',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes',
#    'train': 'yes'}},
#  241928758: {'type': 'node',
#   'id': 241928758,
#   'lat': 48.8454296,
#   'lon': 2.4292592,
#   'tags': {'name': 'Bérault',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes',
#    'wheelchair': 'no'}},
#  243357000: {'type': 'node',
#   'id': 243357000,
#   'lat': 48.8783961,
#   'lon': 2.3812008,
#   'tags': {'STIF:zone': '1',
#    'name': 'Buttes Chaumont',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75119S055H',
#    'ref:FR:RATP': '1936',
#    'ref:FR:STIF': '24683',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1018164',
#    'wikipedia': 'fr:Buttes Chaumont (métro de Paris)'}},
#  243358029: {'type': 'node',
#   'id': 243358029,
#   'lat': 48.8809263,
#   'lon': 2.3739077,
#   'tags': {'STIF:zone': '1',
#    'name': 'Bolivar',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75119S046Y',
#    'ref:FR:RATP': '2014',
#    'ref:FR:STIF': '24685',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wikidata': 'Q891362',
#    'wikipedia': 'fr:Bolivar (métro de Paris)'}},
#  243487863: {'type': 'node',
#   'id': 243487863,
#   'lat': 48.846435,
#   'lon': 2.4184422,
#   'tags': {'name': 'Saint-Mandé',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  243490761: {'type': 'node',
#   'id': 243490761,
#   'lat': 48.8667079,
#   'lon': 2.3833739,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2024-09-15',
#    'name': 'Ménilmontant',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S328P',
#    'ref:FR:RATP': '1754',
#    'ref:FR:STIF': '22116',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q119911',
#    'wikipedia': 'fr:Ménilmontant (métro de Paris)'}},
#  243490762: {'type': 'node',
#   'id': 243490762,
#   'lat': 48.8629496,
#   'lon': 2.3874348,
#   'tags': {'STIF:zone': '1',
#    'name': 'Père Lachaise',
#    'name:ru': 'Пер-Лашез',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75120P017N;75111P018D;75111P017C',
#    'ref:FR:RATP': '1741',
#    'ref:FR:STIF': '22112',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wikidata': 'Q176582',
#    'wikipedia': 'fr:Père Lachaise (métro de Paris)'}},
#  243490763: {'type': 'node',
#   'id': 243490763,
#   'lat': 48.8582563,
#   'lon': 2.3901666,
#   'tags': {'STIF:zone': '1',
#    'name': 'Philippe Auguste',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S412F',
#    'ref:FR:RATP': '1784',
#    'ref:FR:STIF': '22113',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1785459',
#    'wikipedia': 'fr:Philippe Auguste (métro de Paris)'}},
#  243493846: {'type': 'node',
#   'id': 243493846,
#   'lat': 48.869062,
#   'lon': 2.3804698,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2024-09-22',
#    'name': 'Couronnes',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S106Y',
#    'ref:FR:RATP': '1893',
#    'ref:FR:STIF': '22126',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1137705',
#    'wikipedia': 'fr:Couronnes (métro de Paris)'}},
#  243493916: {'type': 'node',
#   'id': 243493916,
#   'lat': 48.8774215,
#   'lon': 2.3710197,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2024-02-13',
#    'name': 'Colonel Fabien',
#    'old_name': 'Combat',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75110S097R',
#    'ref:FR:RATP': '1972',
#    'ref:FR:STIF': '22120',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1110656',
#    'wikipedia': 'fr:Colonel Fabien (métro de Paris)'}},
#  243494175: {'type': 'node',
#   'id': 243494175,
#   'lat': 48.8837582,
#   'lon': 2.3689583},
#  243494176: {'type': 'node',
#   'id': 243494176,
#   'lat': 48.8834515,
#   'lon': 2.3691877},
#  243494178: {'type': 'node',
#   'id': 243494178,
#   'lat': 48.8829292,
#   'lon': 2.3699274},
#  243494180: {'type': 'node',
#   'id': 243494180,
#   'lat': 48.8826763,
#   'lon': 2.3701776},
#  243494334: {'type': 'node',
#   'id': 243494334,
#   'lat': 48.8821884,
#   'lon': 2.3710498,
#   'tags': {'STIF:zone': '1',
#    'name': 'Jaurès',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  243494998: {'type': 'node',
#   'id': 243494998,
#   'lat': 48.8829736,
#   'lon': 2.3446121,
#   'tags': {'name': 'Anvers',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  243496024: {'type': 'node',
#   'id': 243496024,
#   'lat': 48.882386,
#   'lon': 2.3371921},
#  243507233: {'type': 'node',
#   'id': 243507233,
#   'lat': 48.8649387,
#   'lon': 2.4154765,
#   'tags': {'STIF:zone': '1',
#    'alt_name': 'Gallieni (Parc de Bagnolet)',
#    'name': 'Gallieni',
#    'name:ru': 'Гальени',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:RATP': '1928',
#    'subway': 'yes'}},
#  243507235: {'type': 'node',
#   'id': 243507235,
#   'lat': 48.864941,
#   'lon': 2.3978212,
#   'tags': {'name': 'Gambetta',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  243510337: {'type': 'node',
#   'id': 243510337,
#   'lat': 48.8736792,
#   'lon': 2.3273189,
#   'tags': {'STIF:zone': '1',
#    'name': 'Havre - Caumartin',
#    'name:fr': 'Havre - Caumartin',
#    'name:ru': 'Гавр — Комартен',
#    'old_name': 'Caumartin',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75109S223G',
#    'ref:FR:RATP': '1852',
#    'ref:FR:STIF': '21906;21926',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1511406',
#    'wikipedia': 'fr:Havre - Caumartin (métro de Paris)'}},
#  243510338: {'type': 'node',
#   'id': 243510338,
#   'lat': 48.8756144,
#   'lon': 2.3241125,
#   'tags': {'STIF:zone': '1',
#    'addr:city': 'Paris',
#    'addr:postcode': '75009',
#    'addr:street': 'Cour de Rome',
#    'level': '-4',
#    'name': 'Saint-Lazare',
#    'name:ru': 'Сен-Лазар',
#    'network': 'Métro de Paris;RATP',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'start_date': '2003-12-16',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'yes',
#    'wikidata': 'Q1519529',
#    'wikipedia': 'fr:Saint-Lazare (métro de Paris)'}},
#  243510340: {'type': 'node',
#   'id': 243510340,
#   'lat': 48.8794639,
#   'lon': 2.3218438},
#  243510681: {'type': 'node',
#   'id': 243510681,
#   'lat': 48.8859272,
#   'lon': 2.2934906,
#   'tags': {'STIF:zone': '1',
#    'name': 'Porte de Champerret',
#    'name:ru': 'Порт-де-Шанперре',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75117S430B',
#    'ref:FR:RATP': '1722',
#    'ref:FR:STIF': '411230',
#    'source': 'STIF - 12/2016',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q167371',
#    'wikipedia': 'fr:Porte de Champerret (métro de Paris)'}},
#  245250756: {'type': 'node',
#   'id': 245250756,
#   'lat': 48.8478327,
#   'lon': 2.3160019},
#  245250757: {'type': 'node',
#   'id': 245250757,
#   'lat': 48.8507851,
#   'lon': 2.3144281},
#  245250758: {'type': 'node',
#   'id': 245250758,
#   'lat': 48.851398,
#   'lon': 2.3144012,
#   'tags': {'name': 'Saint-François-Xavier',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  245250759: {'type': 'node',
#   'id': 245250759,
#   'lat': 48.8568023,
#   'lon': 2.3150585,
#   'tags': {'name': 'Varenne',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  248573347: {'type': 'node',
#   'id': 248573347,
#   'lat': 48.8152277,
#   'lon': 2.3606559},
#  249335596: {'type': 'node',
#   'id': 249335596,
#   'lat': 48.8905061,
#   'lon': 2.3599967,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2024-07-20',
#    'name': 'Marx Dormoy',
#    'old_name': 'Torcy',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75118S324G',
#    'ref:FR:RATP': '1831',
#    'ref:FR:STIF': '22053',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1622759',
#    'wikipedia': 'fr:Marx Dormoy (métro de Paris)'}},
#  249524466: {'type': 'node',
#   'id': 249524466,
#   'lat': 48.9075274,
#   'lon': 2.3011805},
#  251387813: {'type': 'node',
#   'id': 251387813,
#   'lat': 48.8711191,
#   'lon': 2.3607546,
#   'tags': {'STIF:zone': '1',
#    'name': 'Jacques Bonsergent',
#    'old_name': 'Lancry',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75110S251H',
#    'ref:FR:RATP': '1859',
#    'ref:FR:STIF': '22011',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'yes',
#    'wikidata': 'Q1677923',
#    'wikipedia': 'fr:Jacques Bonsergent (métro de Paris)'}},
#  253020659: {'type': 'node',
#   'id': 253020659,
#   'lat': 48.8453576,
#   'lon': 2.3676625},
#  253020660: {'type': 'node',
#   'id': 253020660,
#   'lat': 48.8451331,
#   'lon': 2.3682795},
#  253020661: {'type': 'node',
#   'id': 253020661,
#   'lat': 48.8447314,
#   'lon': 2.3687626},
#  253020662: {'type': 'node',
#   'id': 253020662,
#   'lat': 48.8445758,
#   'lon': 2.3688448},
#  253020663: {'type': 'node',
#   'id': 253020663,
#   'lat': 48.8444582,
#   'lon': 2.3688639},
#  253020664: {'type': 'node',
#   'id': 253020664,
#   'lat': 48.844265,
#   'lon': 2.3688257},
#  253020665: {'type': 'node',
#   'id': 253020665,
#   'lat': 48.8440733,
#   'lon': 2.3686831},
#  253020666: {'type': 'node',
#   'id': 253020666,
#   'lat': 48.8439465,
#   'lon': 2.368514},
#  253020667: {'type': 'node',
#   'id': 253020667,
#   'lat': 48.8427733,
#   'lon': 2.3665161},
#  253020668: {'type': 'node',
#   'id': 253020668,
#   'lat': 48.8425829,
#   'lon': 2.3660883},
#  253020669: {'type': 'node',
#   'id': 253020669,
#   'lat': 48.8421762,
#   'lon': 2.3650347},
#  253020670: {'type': 'node',
#   'id': 253020670,
#   'lat': 48.8420346,
#   'lon': 2.3645692},
#  253020671: {'type': 'node',
#   'id': 253020671,
#   'lat': 48.8418492,
#   'lon': 2.3637689},
#  253020672: {'type': 'node',
#   'id': 253020672,
#   'lat': 48.8418028,
#   'lon': 2.3636403},
#  253020673: {'type': 'node',
#   'id': 253020673,
#   'lat': 48.8417042,
#   'lon': 2.3634545},
#  253020674: {'type': 'node',
#   'id': 253020674,
#   'lat': 48.8414428,
#   'lon': 2.3631868},
#  253020688: {'type': 'node',
#   'id': 253020688,
#   'lat': 48.838796,
#   'lon': 2.3612057},
#  255000799: {'type': 'node',
#   'id': 255000799,
#   'lat': 48.8920499,
#   'lon': 2.2850318,
#   'tags': {'STIF:zone': '1',
#    'name': 'Anatole France',
#    'name:ru': 'Анатоль Франс',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:RATP': '1982',
#    'ref:FR:STIF': '22036',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q487505',
#    'wikipedia': 'fr:Anatole France (métro de Paris)'}},
#  255160720: {'type': 'node',
#   'id': 255160720,
#   'lat': 48.8579778,
#   'lon': 2.43575,
#   'tags': {'STIF:zone': '1',
#    'alt_name': 'Croix-de-Chavaux (Jacques Duclos)',
#    'name': 'Croix de Chavaux',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:RATP': '1896',
#    'ref:FR:STIF': '21943',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1140796',
#    'wikipedia': 'fr:Croix de Chavaux (métro de Paris)'}},
#  255160722: {'type': 'node',
#   'id': 255160722,
#   'lat': 48.8625988,
#   'lon': 2.441569,
#   'tags': {'STIF:zone': '1',
#    'name': 'Mairie de Montreuil',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:RATP': '1817',
#    'ref:FR:STIF': '21941',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q668351',
#    'wikipedia': 'fr:Mairie de Montreuil (métro de Paris)'}},
#  255161921: {'type': 'node',
#   'id': 255161921,
#   'lat': 48.8971408,
#   'lon': 2.2803973,
#   'tags': {'STIF:zone': '1',
#    'alt_name': 'Pont de Levallois-Bécon',
#    'description:route_ref': 'Métropolitain parisien;ligne 3.',
#    'internet_access': 'yes',
#    'internet_access:fee': 'no',
#    'name': 'Pont de Levallois - Bécon',
#    'name:fr': 'Pont de Levallois - Bécon',
#    'name:ru': 'Пон-де-Левалюа - Бекон',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:RATP': '1708',
#    'ref:FR:STIF': '22035',
#    'route_ref': '3',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1969462',
#    'wikipedia': 'fr:Pont de Levallois - Bécon (métro de Paris)'}},
#  255162203: {'type': 'node',
#   'id': 255162203,
#   'lat': 48.8882803,
#   'lon': 2.2884734,
#   'tags': {'STIF:zone': '1',
#    'name': 'Louise Michel',
#    'name:ru': 'Луиз Мишель',
#    'old_name': 'Vallier',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:RATP': '1807',
#    'ref:FR:STIF': '22034',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wikidata': 'Q1785287',
#    'wikipedia': 'fr:Louise Michel (métro de Paris)'}},
#  256442845: {'type': 'node',
#   'id': 256442845,
#   'lat': 48.8558145,
#   'lon': 2.4237108,
#   'tags': {'STIF:zone': '1',
#    'name': 'Robespierre',
#    'name:ru': 'Робеспьер',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:RATP': '1667',
#    'ref:FR:STIF': '21942',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1784141',
#    'wikipedia': 'fr:Robespierre (métro de Paris)'}},
#  256443205: {'type': 'node',
#   'id': 256443205,
#   'lat': 48.8525808,
#   'lon': 2.3887914,
#   'tags': {'STIF:zone': '1',
#    'name': 'Rue des Boulets',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S050M',
#    'ref:FR:RATP': '1673',
#    'ref:FR:STIF': '22442',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1969472',
#    'wikipedia': 'fr:Rue des Boulets (métro de Paris)'}},
#  256897080: {'type': 'node',
#   'id': 256897080,
#   'lat': 48.8717041,
#   'lon': 2.3385398,
#   'tags': {'STIF:zone': '1',
#    'level': '-2',
#    'name': 'Richelieu - Drouot',
#    'name:ru': 'Ришельё — Друо',
#    'network': 'RATP',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75109S488V',
#    'ref:FR:RATP': '1665',
#    'ref:FR:STIF': '22196',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1412692',
#    'wikipedia': 'fr:Richelieu - Drouot (métro de Paris)'}},
#  256897554: {'type': 'node',
#   'id': 256897554,
#   'lat': 48.874471,
#   'lon': 2.3217921,
#   'tags': {'STIF:zone': '1',
#    'name': 'Saint-Augustin',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75108S511D',
#    'ref:FR:RATP': '1681',
#    'ref:FR:STIF': '21911',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q649273',
#    'wikipedia': 'fr:Saint-Augustin (métro de Paris)'}},
#  257466487: {'type': 'node',
#   'id': 257466487,
#   'lat': 48.8820099,
#   'lon': 2.3398161},
#  257613002: {'type': 'node',
#   'id': 257613002,
#   'lat': 48.831941,
#   'lon': 2.3590006},
#  258068720: {'type': 'node',
#   'id': 258068720,
#   'lat': 48.8454709,
#   'lon': 2.3673171},
#  258068721: {'type': 'node',
#   'id': 258068721,
#   'lat': 48.84568,
#   'lon': 2.3669022},
#  258068722: {'type': 'node',
#   'id': 258068722,
#   'lat': 48.8457923,
#   'lon': 2.3667523},
#  258068723: {'type': 'node',
#   'id': 258068723,
#   'lat': 48.8462775,
#   'lon': 2.3661298},
#  258068724: {'type': 'node',
#   'id': 258068724,
#   'lat': 48.8464731,
#   'lon': 2.3658858,
#   'tags': {'name': 'Quai de la Rapée',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  258068725: {'type': 'node',
#   'id': 258068725,
#   'lat': 48.8465632,
#   'lon': 2.3657787},
#  258068726: {'type': 'node',
#   'id': 258068726,
#   'lat': 48.8467544,
#   'lon': 2.3656201},
#  258068727: {'type': 'node',
#   'id': 258068727,
#   'lat': 48.847081,
#   'lon': 2.3654916},
#  258068728: {'type': 'node',
#   'id': 258068728,
#   'lat': 48.847302,
#   'lon': 2.3654793},
#  258068729: {'type': 'node',
#   'id': 258068729,
#   'lat': 48.847571,
#   'lon': 2.365638},
#  259439346: {'type': 'node',
#   'id': 259439346,
#   'lat': 48.8844092,
#   'lon': 2.3300563},
#  260040968: {'type': 'node',
#   'id': 260040968,
#   'lat': 48.8459933,
#   'lon': 2.3551119},
#  260079008: {'type': 'node',
#   'id': 260079008,
#   'lat': 48.8522212,
#   'lon': 2.3393289,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2021-09-17',
#    'name': 'Odéon',
#    'name:ru': 'Одеон',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75106S382B',
#    'ref:FR:RATP': '1770',
#    'source': 'STIF - 12/2016',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no'}},
#  260231828: {'type': 'node',
#   'id': 260231828,
#   'lat': 48.8363968,
#   'lon': 2.278379,
#   'tags': {'STIF:zone': '1',
#    'name': 'Balard',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75115S034G',
#    'ref:FR:RATP': '1997;1609',
#    'ref:FR:STIF': '22186',
#    'source': 'STIF, 12/2016 - Île-de-France Mobilités, 01/2024',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q804647',
#    'wikipedia': 'fr:Balard (métro de Paris)'}},
#  260231831: {'type': 'node',
#   'id': 260231831,
#   'lat': 48.8387364,
#   'lon': 2.2821481,
#   'tags': {'STIF:zone': '1',
#    'name': 'Lourmel',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75115S292M',
#    'ref:FR:RATP': '1808;1610',
#    'ref:FR:STIF': '22187',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1651903',
#    'wikipedia': 'fr:Lourmel (métro de Paris)'}},
#  260231832: {'type': 'node',
#   'id': 260231832,
#   'lat': 48.8410837,
#   'lon': 2.2879218,
#   'tags': {'STIF:zone': '1',
#    'name': 'Boucicaut',
#    'network': 'RATP',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75115S049Y',
#    'ref:FR:RATP': '2017;1611',
#    'ref:FR:STIF': '22188',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q894984',
#    'wikipedia': 'fr:Boucicaut (métro de Paris)'}},
#  260231833: {'type': 'node',
#   'id': 260231833,
#   'lat': 48.8426775,
#   'lon': 2.2917792,
#   'tags': {'STIF:zone': '1',
#    'addr:city': 'Paris',
#    'name': 'Félix Faure',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75115S163X',
#    'ref:FR:RATP': '1612;1925',
#    'ref:FR:STIF': '22189',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1479476',
#    'wikipedia': 'fr:Félix Faure (métro de Paris)'}},
#  260763474: {'type': 'node',
#   'id': 260763474,
#   'lat': 48.8410969,
#   'lon': 2.3250718,
#   'tags': {'name': 'Edgar Quinet',
#    'network': 'Métro de Paris',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'station': 'subway',
#    'subway': 'yes',
#    'wikidata': 'Q56707803'}},
#  260765391: {'type': 'node',
#   'id': 260765391,
#   'lat': 48.850667,
#   'lon': 2.2928957},
#  260767422: {'type': 'node',
#   'id': 260767422,
#   'lat': 48.8646177,
#   'lon': 2.2937179,
#   'tags': {'STIF:zone': '1',
#    'name': 'Iéna',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S241C',
#    'ref:FR:RATP': '1858',
#    'ref:FR:STIF': '21927',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1237945',
#    'wikipedia': 'fr:Iéna (métro de Paris)'}},
#  260767423: {'type': 'node',
#   'id': 260767423,
#   'lat': 48.8640672,
#   'lon': 2.278149,
#   'tags': {'STIF:zone': '1',
#    'alt_name': 'Rue de la Pompe (Avenue Georges Mandel)',
#    'name': 'Rue de la Pompe',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S421Y',
#    'ref:FR:RATP': '1672',
#    'ref:FR:STIF': '21908',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q771548',
#    'wikipedia': 'fr:Rue de la Pompe (métro de Paris)'}},
#  260767424: {'type': 'node',
#   'id': 260767424,
#   'lat': 48.8579754,
#   'lon': 2.274062,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2021-10-28',
#    'name': 'La Muette',
#    'name:ru': 'Ля-Мюэт',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S340K',
#    'ref:FR:RATP': '1876',
#    'ref:FR:STIF': '21929',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q168170',
#    'wikipedia': 'fr:La Muette (métro de Paris)'}},
#  260767425: {'type': 'node',
#   'id': 260767425,
#   'lat': 48.8555764,
#   'lon': 2.2702166,
#   'tags': {'STIF:zone': '1',
#    'name': 'Ranelagh',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S482P',
#    'ref:FR:RATP': '1659',
#    'ref:FR:STIF': '21915',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1969938',
#    'wikipedia': 'fr:Ranelagh (métro de Paris)'}},
#  260767426: {'type': 'node',
#   'id': 260767426,
#   'lat': 48.8525598,
#   'lon': 2.2681802,
#   'tags': {'STIF:zone': '1',
#    'name': 'Jasmin',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S252P',
#    'ref:FR:RATP': '1860',
#    'ref:FR:STIF': '21928',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1683797',
#    'wikipedia': 'fr:Jasmin (métro de Paris)'}},
#  260767427: {'type': 'node',
#   'id': 260767427,
#   'lat': 48.8479434,
#   'lon': 2.2641344},
#  260767429: {'type': 'node',
#   'id': 260767429,
#   'lat': 48.8430044,
#   'lon': 2.2600472,
#   'tags': {'STIF:zone': '1',
#    'name': 'Exelmans',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S149C',
#    'ref:FR:RATP': '1916',
#    'ref:FR:STIF': '21930',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q970844',
#    'wikipedia': 'fr:Exelmans (métro de Paris)'}},
#  260767430: {'type': 'node',
#   'id': 260767430,
#   'lat': 48.8377707,
#   'lon': 2.2565741,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2021-06-27',
#    'name': 'Porte de Saint-Cloud',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75116S445Z',
#    'ref:FR:RATP': '1729',
#    'ref:FR:STIF': '21914',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1451224',
#    'wikipedia': 'fr:Porte de Saint-Cloud (métro de Paris)'}},
#  260769132: {'type': 'node',
#   'id': 260769132,
#   'lat': 48.8648683,
#   'lon': 2.300292,
#   'tags': {'STIF:zone': '1',
#    'name': 'Alma-Marceau',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75108S004C',
#    'ref:FR:RATP': '1980',
#    'ref:FR:STIF': '21935',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1768692',
#    'wikipedia': 'fr:Alma - Marceau (métro de Paris)'}},
#  260769651: {'type': 'node',
#   'id': 260769651,
#   'lat': 48.8723362,
#   'lon': 2.3100827,
#   'tags': {'STIF:zone': '1',
#    'name': 'Saint-Philippe du Roule',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75108S524T',
#    'ref:FR:RATP': '1696',
#    'ref:FR:STIF': '21912',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1784247',
#    'wikipedia': 'fr:Saint-Philippe du Roule (métro de Paris)'}},
#  260928397: {'type': 'node',
#   'id': 260928397,
#   'lat': 48.8710863,
#   'lon': 2.3035097},
#  261611231: {'type': 'node',
#   'id': 261611231,
#   'lat': 48.9146941,
#   'lon': 2.2965039},
#  261611854: {'type': 'node',
#   'id': 261611854,
#   'lat': 48.8969923,
#   'lon': 2.3103048},
#  261665441: {'type': 'node',
#   'id': 261665441,
#   'lat': 48.848769,
#   'lon': 2.3211716},
#  261665873: {'type': 'node',
#   'id': 261665873,
#   'lat': 48.8488956,
#   'lon': 2.3045312},
#  263917855: {'type': 'node',
#   'id': 263917855,
#   'lat': 48.8622815,
#   'lon': 2.3197801},
#  263917856: {'type': 'node',
#   'id': 263917856,
#   'lat': 48.8656344,
#   'lon': 2.3227573,
#   'tags': {'STIF:zone': '1',
#    'name': 'Concorde',
#    'name:de': 'Eintracht',
#    'name:es': 'Concordia',
#    'name:it': 'Concorde',
#    'name:pt': 'Concórdia',
#    'name:ru': 'Конкорд',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:RATP': '1885',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q970075',
#    'wikipedia': 'fr:Concorde (métro de Paris)'}},
#  264100941: {'type': 'node',
#   'id': 264100941,
#   'lat': 48.8619826,
#   'lon': 2.4413822},
#  264117312: {'type': 'node',
#   'id': 264117312,
#   'lat': 48.8694342,
#   'lon': 2.3251717},
#  264117790: {'type': 'node',
#   'id': 264117790,
#   'lat': 48.8702329,
#   'lon': 2.3252463,
#   'tags': {'name': 'Madeleine',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  264469160: {'type': 'node',
#   'id': 264469160,
#   'lat': 48.8447112,
#   'lon': 2.2938643,
#   'tags': {'STIF:zone': '1',
#    'name': 'Commerce',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75115S098B',
#    'ref:FR:RATP': '1705;1973',
#    'ref:FR:STIF': '22190',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q608305',
#    'wikipedia': 'fr:Commerce (métro de Paris)'}},
#  264469541: {'type': 'node',
#   'id': 264469541,
#   'lat': 48.8546647,
#   'lon': 2.3060728,
#   'tags': {'STIF:zone': '1',
#    'name': 'École Militaire',
#    'name:fr': 'École Militaire',
#    'name:ru': 'Эколь Милитер',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75107S141H',
#    'ref:FR:RATP': '1909;1007',
#    'ref:FR:STIF': '22191',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q273476',
#    'wikipedia': 'fr:École Militaire (métro de Paris)'}},
#  264473011: {'type': 'node',
#   'id': 264473011,
#   'lat': 48.8575602,
#   'lon': 2.3103234,
#   'tags': {'STIF:zone': '1',
#    'addr:city': 'Paris',
#    'name': 'La Tour Maubourg',
#    'name:ru': 'Лятур-Мобур',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75107S285P',
#    'ref:FR:RATP': '1008;54166',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1514082',
#    'wikipedia': 'fr:La Tour-Maubourg (métro de Paris)'}},
#  264473695: {'type': 'node',
#   'id': 264473695,
#   'lat': 48.859683,
#   'lon': 2.314484,
#   'tags': {'STIF:zone': '1',
#    'name': 'Invalides',
#    'name:ru': 'Энвалид',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:RATP': '1857',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1528456',
#    'wikipedia': 'fr:Invalides (métro de Paris)'}},
#  264475082: {'type': 'node',
#   'id': 264475082,
#   'lat': 48.8718889,
#   'lon': 2.3404573},
#  264475311: {'type': 'node',
#   'id': 264475311,
#   'lat': 48.8716692,
#   'lon': 2.3422268},
#  264476971: {'type': 'node',
#   'id': 264476971,
#   'lat': 48.8633194,
#   'lon': 2.3666323,
#   'tags': {'STIF:zone': '1',
#    'name': 'Filles du Calvaire',
#    'name:ru': 'Фий-дю-Кальвер',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S164L',
#    'ref:FR:RATP': '1919',
#    'ref:FR:STIF': '22200',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1414178',
#    'wikipedia': 'fr:Filles du Calvaire (métro de Paris)'}},
#  264479724: {'type': 'node',
#   'id': 264479724,
#   'lat': 48.8611816,
#   'lon': 2.367234,
#   'tags': {'STIF:zone': '1',
#    'name': 'Saint-Sébastien - Froissart',
#    'name:ru': 'Сен-Себастьен — Фруассар',
#    'operator': 'RATP',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S527F',
#    'ref:FR:RATP': '1699',
#    'ref:FR:STIF': '22201',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q550042',
#    'wikipedia': 'fr:Saint-Sébastien - Froissart (métro de Paris)'}},
#  264479775: {'type': 'node',
#   'id': 264479775,
#   'lat': 48.8574434,
#   'lon': 2.3681408,
#   'tags': {'STIF:zone': '1',
#    'name': 'Chemin Vert',
#    'name:ru': 'Шемен-Вер',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S093J',
#    'ref:FR:RATP': '1958',
#    'ref:FR:STIF': '22202',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'toilets:wheelchair': 'no',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q524191',
#    'wikipedia': 'fr:Chemin Vert (métro de Paris)'}},
#  264480619: {'type': 'node',
#   'id': 264480619,
#   'lat': 48.8532438,
#   'lon': 2.3685718,
#   'tags': {'name': 'Bastille',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  264480784: {'type': 'node',
#   'id': 264480784,
#   'lat': 48.8512945,
#   'lon': 2.3760274,
#   'tags': {'STIF:zone': '1',
#    'name': 'Ledru-Rollin',
#    'name:ru': 'Ледрю-Роллен',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75112S287R',
#    'ref:FR:RATP': '1798',
#    'ref:FR:STIF': '22203',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q680787',
#    'wikipedia': 'fr:Ledru-Rollin (métro de Paris)'}},
#  264481019: {'type': 'node',
#   'id': 264481019,
#   'lat': 48.8501609,
#   'lon': 2.3842222,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2021-11-19',
#    'name': 'Faidherbe — Chaligny',
#    'name:ru': 'Федерб — Шалиньи',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75111S161H',
#    'ref:FR:RATP': '1917',
#    'ref:FR:STIF': '22204',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q337855',
#    'wikipedia': 'fr:Faidherbe - Chaligny (métro de Paris)'}},
#  264481854: {'type': 'node',
#   'id': 264481854,
#   'lat': 48.844304,
#   'lon': 2.3901962,
#   'tags': {'STIF:zone': '1',
#    'name': 'Montgallet',
#    'name:ru': 'Монгале',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75112S336U',
#    'ref:FR:RATP': '1750',
#    'ref:FR:STIF': '22205',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q999159',
#    'wikipedia': 'fr:Montgallet (métro de Paris)'}},
#  264482226: {'type': 'node',
#   'id': 264482226,
#   'lat': 48.8370694,
#   'lon': 2.4024586,
#   'tags': {'STIF:zone': '1',
#    'check_date:wheelchair': '2021-03-02',
#    'name': 'Michel Bizot',
#    'name:ru': 'Мишель Бизо',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75112S331N',
#    'ref:FR:RATP': '1835',
#    'ref:FR:STIF': '22206',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q616619',
#    'wikipedia': 'fr:Michel Bizot (métro de Paris)'}},
#  264482296: {'type': 'node',
#   'id': 264482296,
#   'lat': 48.8264064,
#   'lon': 2.406201,
#   'tags': {'STIF:zone': '1',
#    'name': 'Liberté',
#    'name:ru': 'Либерте',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:RATP': '1803',
#    'ref:FR:STIF': '22209',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1725892',
#    'wikipedia': 'fr:Liberté (métro de Paris)'}},
#  264482297: {'type': 'node',
#   'id': 264482297,
#   'lat': 48.8352765,
#   'lon': 2.4061775,
#   'tags': {'STIF:zone': '1',
#    'name': 'Porte Dorée',
#    'name:fr': 'Porte Dorée',
#    'name:ru': 'Порт-Доре',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75112S437D',
#    'ref:FR:RATP': '1715',
#    'ref:FR:STIF': '22207',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q946441',
#    'wikipedia': 'fr:Porte Dorée (métro de Paris)'}},
#  264491193: {'type': 'node',
#   'id': 264491193,
#   'lat': 48.8270333,
#   'lon': 2.3664158,
#   'tags': {'name': 'Olympiades',
#    'network': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  264491320: {'type': 'node',
#   'id': 264491320,
#   'lat': 48.8322315,
#   'lon': 2.3990408,
#   'tags': {'STIF:zone': '1',
#    'name': 'Porte de Charenton',
#    'name:ru': 'Порт-де-Шарантон',
#    'public_transport': 'station',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75112S432Y',
#    'ref:FR:RATP': '1723',
#    'ref:FR:STIF': '22208',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1666283',
#    'wikipedia': 'fr:Porte de Charenton (métro de Paris)'}},
#  264494507: {'type': 'node',
#   'id': 264494507,
#   'lat': 48.8657589,
#   'lon': 2.3344261},
#  264505930: {'type': 'node',
#   'id': 264505930,
#   'lat': 48.8977035,
#   'lon': 2.3594563,
#   'tags': {'STIF:zone': '1',
#    'layer': '-4',
#    'name': 'Porte de la Chapelle',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:RATP': '1734',
#    'ref:FR:STIF': '22041',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'limited',
#    'wikidata': 'Q382659',
#    'wikipedia': 'fr:Porte de la Chapelle (métro de Paris)'}},
#  264505993: {'type': 'node',
#   'id': 264505993,
#   'lat': 48.8938481,
#   'lon': 2.3478412,
#   'tags': {'STIF:zone': '1',
#    'name': 'Simplon',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75118S534K',
#    'ref:FR:RATP': '1621',
#    'ref:FR:STIF': '22133',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q163879',
#    'wikipedia': 'fr:Simplon (métro de Paris)'}},
#  264507100: {'type': 'node',
#   'id': 264507100,
#   'lat': 48.8868654,
#   'lon': 2.3495534,
#   'tags': {'name': 'Château Rouge',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  264509793: {'type': 'node',
#   'id': 264509793,
#   'lat': 48.8639526,
#   'lon': 2.3493931,
#   'tags': {'STIF:zone': '1',
#    'name': 'Étienne Marcel',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75101S146H',
#    'ref:FR:RATP': '1914',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q289916',
#    'wikipedia': 'fr:Étienne Marcel (métro de Paris)'}},
#  264512252: {'type': 'node',
#   'id': 264512252,
#   'lat': 48.8728919,
#   'lon': 2.3563063,
#   'tags': {'STIF:zone': '1',
#    'heritage': '3',
#    'heritage:operator': 'mhs',
#    'mhs:inscription_date': '1978',
#    'name': "Château d'Eau",
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75110S086D',
#    'ref:FR:RATP': '1961',
#    'ref:mhs': 'PA00086508',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1090753',
#    'wikipedia': "fr:Château d'Eau (métro de Paris)"}},
#  264513655: {'type': 'node',
#   'id': 264513655,
#   'lat': 48.8621801,
#   'lon': 2.3458118,
#   'tags': {'STIF:zone': '1',
#    'name': 'Les Halles',
#    'opening_hours': 'Mo-Sa 10:00-20:30; Su 11:00-19:00',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75101S222R',
#    'ref:FR:RATP': '1801',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wikidata': 'Q1576810',
#    'wikipedia': 'fr:Les Halles (métro de Paris)'}},
#  264704365: {'type': 'node',
#   'id': 264704365,
#   'lat': 48.8386332,
#   'lon': 2.3224866,
#   'tags': {'STIF:zone': '1',
#    'alt_name': 'Gaîté – Joséphine Baker',
#    'check_date:wheelchair': '2021-05-27',
#    'name': 'Gaîté',
#    'name:ru': 'Гаите',
#    'old_name': 'Gaîté',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:FANTOIR': '75114S181Y',
#    'ref:FR:RATP': '1927',
#    'ref:FR:STIF': '22230',
#    'source': 'STIF - 12/2016',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q377782',
#    'wikipedia': 'fr:Gaîté (métro de Paris)'}},
#  264712432: {'type': 'node',
#   'id': 264712432,
#   'lat': 48.8317757,
#   'lon': 2.3140286,
#   'tags': {'name': 'Plaisance',
#    'name:ru': 'Плезанс',
# ...
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499641263: {'type': 'node',
#   'id': 1499641263,
#   'lat': 48.8478253,
#   'lon': 2.3018675},
#  1499641265: {'type': 'node',
#   'id': 1499641265,
#   'lat': 48.8480088,
#   'lon': 2.3012806},
#  1499641425: {'type': 'node',
#   'id': 1499641425,
#   'lat': 48.8484324,
#   'lon': 2.2998919},
#  1499641471: {'type': 'node',
#   'id': 1499641471,
#   'lat': 48.8485822,
#   'lon': 2.299414},
#  1499641515: {'type': 'node',
#   'id': 1499641515,
#   'lat': 48.8488942,
#   'lon': 2.2983974},
#  1499641562: {'type': 'node',
#   'id': 1499641562,
#   'lat': 48.8490263,
#   'lon': 2.2979698,
#   'tags': {'name': 'La Motte-Picquet - Grenelle',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499641572: {'type': 'node',
#   'id': 1499641572,
#   'lat': 48.8491039,
#   'lon': 2.2977446,
#   'tags': {'railway': 'switch'}},
#  1499641613: {'type': 'node',
#   'id': 1499641613,
#   'lat': 48.8492393,
#   'lon': 2.2974141,
#   'tags': {'railway': 'switch'}},
#  1499641646: {'type': 'node',
#   'id': 1499641646,
#   'lat': 48.8492791,
#   'lon': 2.2971624},
#  1499641746: {'type': 'node',
#   'id': 1499641746,
#   'lat': 48.8495,
#   'lon': 2.2964713},
#  1499641869: {'type': 'node',
#   'id': 1499641869,
#   'lat': 48.8497221,
#   'lon': 2.2957653},
#  1499641874: {'type': 'node',
#   'id': 1499641874,
#   'lat': 48.8497388,
#   'lon': 2.2958076},
#  1499641968: {'type': 'node',
#   'id': 1499641968,
#   'lat': 48.8499138,
#   'lon': 2.2951647},
#  1499642019: {'type': 'node',
#   'id': 1499642019,
#   'lat': 48.8500271,
#   'lon': 2.2949054},
#  1499642081: {'type': 'node',
#   'id': 1499642081,
#   'lat': 48.8501496,
#   'lon': 2.2944583},
#  1499642088: {'type': 'node',
#   'id': 1499642088,
#   'lat': 48.8505848,
#   'lon': 2.2930588},
#  1499642089: {'type': 'node',
#   'id': 1499642089,
#   'lat': 48.8505691,
#   'lon': 2.2932004,
#   'tags': {'name': 'Dupleix',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499642090: {'type': 'node',
#   'id': 1499642090,
#   'lat': 48.8506506,
#   'lon': 2.2928537},
#  1499642091: {'type': 'node',
#   'id': 1499642091,
#   'lat': 48.8506772,
#   'lon': 2.2927683},
#  1499642092: {'type': 'node',
#   'id': 1499642092,
#   'lat': 48.8506985,
#   'lon': 2.2927065},
#  1499642093: {'type': 'node',
#   'id': 1499642093,
#   'lat': 48.8507333,
#   'lon': 2.2926205},
#  1499642094: {'type': 'node',
#   'id': 1499642094,
#   'lat': 48.8507354,
#   'lon': 2.2926956},
#  1499642096: {'type': 'node',
#   'id': 1499642096,
#   'lat': 48.8507558,
#   'lon': 2.2926493},
#  1499642097: {'type': 'node',
#   'id': 1499642097,
#   'lat': 48.8507696,
#   'lon': 2.2925485},
#  1499642098: {'type': 'node',
#   'id': 1499642098,
#   'lat': 48.8507986,
#   'lon': 2.2924907},
#  1499642099: {'type': 'node',
#   'id': 1499642099,
#   'lat': 48.8508281,
#   'lon': 2.2924421},
#  1499642100: {'type': 'node',
#   'id': 1499642100,
#   'lat': 48.8508566,
#   'lon': 2.2924621},
#  1499642101: {'type': 'node',
#   'id': 1499642101,
#   'lat': 48.8508614,
#   'lon': 2.2923934},
#  1499642102: {'type': 'node',
#   'id': 1499642102,
#   'lat': 48.8508947,
#   'lon': 2.2923486},
#  1499642104: {'type': 'node',
#   'id': 1499642104,
#   'lat': 48.8509155,
#   'lon': 2.2923785},
#  1499642105: {'type': 'node',
#   'id': 1499642105,
#   'lat': 48.8509323,
#   'lon': 2.2923028},
#  1499642106: {'type': 'node',
#   'id': 1499642106,
#   'lat': 48.8509782,
#   'lon': 2.2922522},
#  1499642107: {'type': 'node',
#   'id': 1499642107,
#   'lat': 48.8510054,
#   'lon': 2.292272},
#  1499642108: {'type': 'node',
#   'id': 1499642108,
#   'lat': 48.851169,
#   'lon': 2.2920595},
#  1499642109: {'type': 'node',
#   'id': 1499642109,
#   'lat': 48.8516217,
#   'lon': 2.2916091},
#  1499642111: {'type': 'node',
#   'id': 1499642111,
#   'lat': 48.8517691,
#   'lon': 2.291514},
#  1499642112: {'type': 'node',
#   'id': 1499642112,
#   'lat': 48.8521602,
#   'lon': 2.2911248},
#  1499642113: {'type': 'node',
#   'id': 1499642113,
#   'lat': 48.8521892,
#   'lon': 2.2910481},
#  1499642114: {'type': 'node',
#   'id': 1499642114,
#   'lat': 48.8525509,
#   'lon': 2.2906884},
#  1499642115: {'type': 'node',
#   'id': 1499642115,
#   'lat': 48.8530927,
#   'lon': 2.2901493},
#  1499642116: {'type': 'node',
#   'id': 1499642116,
#   'lat': 48.853629,
#   'lon': 2.2896041,
#   'tags': {'name': 'Bir-Hakeim',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499642117: {'type': 'node',
#   'id': 1499642117,
#   'lat': 48.8542487,
#   'lon': 2.2890465,
#   'tags': {'name': 'Bir-Hakeim',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499642118: {'type': 'node',
#   'id': 1499642118,
#   'lat': 48.854255,
#   'lon': 2.2889942},
#  1499642123: {'type': 'node',
#   'id': 1499642123,
#   'lat': 48.855289,
#   'lon': 2.2879618},
#  1499642124: {'type': 'node',
#   'id': 1499642124,
#   'lat': 48.8556411,
#   'lon': 2.2876117},
#  1499642125: {'type': 'node',
#   'id': 1499642125,
#   'lat': 48.8565599,
#   'lon': 2.2866921},
#  1499642126: {'type': 'node',
#   'id': 1499642126,
#   'lat': 48.8568775,
#   'lon': 2.2863804},
#  1499642127: {'type': 'node',
#   'id': 1499642127,
#   'lat': 48.8573099,
#   'lon': 2.2859462,
#   'tags': {'name': 'Passy',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1499642128: {'type': 'node',
#   'id': 1499642128,
#   'lat': 48.8576352,
#   'lon': 2.285619},
#  1509815548: {'type': 'node',
#   'id': 1509815548,
#   'lat': 48.8427605,
#   'lon': 2.2919388},
#  1509815553: {'type': 'node',
#   'id': 1509815553,
#   'lat': 48.8428602,
#   'lon': 2.2920877},
#  1509898448: {'type': 'node',
#   'id': 1509898448,
#   'lat': 48.8615641,
#   'lon': 2.3388288},
#  1509898503: {'type': 'node',
#   'id': 1509898503,
#   'lat': 48.8635907,
#   'lon': 2.332476},
#  1528156934: {'type': 'node',
#   'id': 1528156934,
#   'lat': 48.8424676,
#   'lon': 2.3923869,
#   'tags': {'crossing': 'uncontrolled',
#    'crossing:island': 'no',
#    'crossing:markings': 'zebra',
#    'crossing_ref': 'zebra',
#    'highway': 'crossing',
#    'tactile_paving': 'yes'}},
#  1555909630: {'type': 'node',
#   'id': 1555909630,
#   'lat': 48.8315201,
#   'lon': 2.2366849},
#  1555909632: {'type': 'node',
#   'id': 1555909632,
#   'lat': 48.8315485,
#   'lon': 2.2366665},
#  1555909633: {'type': 'node',
#   'id': 1555909633,
#   'lat': 48.8319353,
#   'lon': 2.238046},
#  1555909635: {'type': 'node',
#   'id': 1555909635,
#   'lat': 48.8319588,
#   'lon': 2.2380285},
#  1584432755: {'type': 'node',
#   'id': 1584432755,
#   'lat': 48.8524743,
#   'lon': 2.3717922},
#  1584432756: {'type': 'node',
#   'id': 1584432756,
#   'lat': 48.852972,
#   'lon': 2.3707596},
#  1584432757: {'type': 'node',
#   'id': 1584432757,
#   'lat': 48.8526923,
#   'lon': 2.3713054},
#  1584432758: {'type': 'node',
#   'id': 1584432758,
#   'lat': 48.8530654,
#   'lon': 2.3705485},
#  1584432759: {'type': 'node',
#   'id': 1584432759,
#   'lat': 48.8532989,
#   'lon': 2.3698275},
#  1584432760: {'type': 'node',
#   'id': 1584432760,
#   'lat': 48.8536788,
#   'lon': 2.3691871,
#   'tags': {'name': 'Bastille',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1584432761: {'type': 'node',
#   'id': 1584432761,
#   'lat': 48.8540968,
#   'lon': 2.3689203},
#  1584432763: {'type': 'node',
#   'id': 1584432763,
#   'lat': 48.8522067,
#   'lon': 2.3678111},
#  1584432764: {'type': 'node',
#   'id': 1584432764,
#   'lat': 48.8524111,
#   'lon': 2.3679476},
#  1584432765: {'type': 'node',
#   'id': 1584432765,
#   'lat': 48.8540646,
#   'lon': 2.3692558},
#  1584432766: {'type': 'node',
#   'id': 1584432766,
#   'lat': 48.853587,
#   'lon': 2.3687394},
#  1600601237: {'type': 'node',
#   'id': 1600601237,
#   'lat': 48.7824559,
#   'lon': 2.4591855},
#  1600627491: {'type': 'node',
#   'id': 1600627491,
#   'lat': 48.7712483,
#   'lon': 2.4629302},
#  1600627504: {'type': 'node',
#   'id': 1600627504,
#   'lat': 48.7734607,
#   'lon': 2.4618442},
#  1600627530: {'type': 'node',
#   'id': 1600627530,
#   'lat': 48.7776829,
#   'lon': 2.4595214},
#  1600999382: {'type': 'node',
#   'id': 1600999382,
#   'lat': 48.8491832,
#   'lon': 2.3970582},
#  1605835901: {'type': 'node',
#   'id': 1605835901,
#   'lat': 48.8459629,
#   'lon': 2.4235276},
#  1606203726: {'type': 'node',
#   'id': 1606203726,
#   'lat': 48.816447,
#   'lon': 2.2960694},
#  1606203747: {'type': 'node',
#   'id': 1606203747,
#   'lat': 48.817564,
#   'lon': 2.2954708},
#  1606203751: {'type': 'node',
#   'id': 1606203751,
#   'lat': 48.8182757,
#   'lon': 2.295308},
#  1621528078: {'type': 'node',
#   'id': 1621528078,
#   'lat': 48.7704802,
#   'lon': 2.4632567},
#  1626986167: {'type': 'node',
#   'id': 1626986167,
#   'lat': 48.8770151,
#   'lon': 2.3940441},
#  1631588948: {'type': 'node',
#   'id': 1631588948,
#   'lat': 48.8352348,
#   'lon': 2.277803},
#  1631588974: {'type': 'node',
#   'id': 1631588974,
#   'lat': 48.8357452,
#   'lon': 2.2780765},
#  1631589024: {'type': 'node',
#   'id': 1631589024,
#   'lat': 48.8358892,
#   'lon': 2.2781441},
#  1631589040: {'type': 'node',
#   'id': 1631589040,
#   'lat': 48.8360372,
#   'lon': 2.2782017},
#  1631589044: {'type': 'node',
#   'id': 1631589044,
#   'lat': 48.8362695,
#   'lon': 2.2783177},
#  1631589064: {'type': 'node',
#   'id': 1631589064,
#   'lat': 48.836994,
#   'lon': 2.2788445},
#  1640452955: {'type': 'node',
#   'id': 1640452955,
#   'lat': 48.8403483,
#   'lon': 2.2581737,
#   'tags': {'crossing': 'uncontrolled',
#    'crossing:markings': 'zebra',
#    'crossing:signals': 'no',
#    'crossing_ref': 'zebra',
#    'highway': 'crossing',
#    'source': 'survey',
#    'tactile_paving': 'yes'}},
#  1656938775: {'type': 'node',
#   'id': 1656938775,
#   'lat': 48.8434008,
#   'lon': 2.3739596,
#   'tags': {'layer': '-3',
#    'level': '-2',
#    'name': 'Gare de Lyon',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'yes'}},
#  1666065919: {'type': 'node',
#   'id': 1666065919,
#   'lat': 48.8801896,
#   'lon': 2.353796},
#  1701257372: {'type': 'node',
#   'id': 1701257372,
#   'lat': 48.790419,
#   'lon': 2.4500141},
#  1701257377: {'type': 'node',
#   'id': 1701257377,
#   'lat': 48.7910124,
#   'lon': 2.4494439},
#  1701257380: {'type': 'node',
#   'id': 1701257380,
#   'lat': 48.7905043,
#   'lon': 2.4500531},
#  1701257391: {'type': 'node',
#   'id': 1701257391,
#   'lat': 48.7893721,
#   'lon': 2.4510256},
#  1701257396: {'type': 'node',
#   'id': 1701257396,
#   'lat': 48.7915288,
#   'lon': 2.4489772},
#  1701257398: {'type': 'node',
#   'id': 1701257398,
#   'lat': 48.7896637,
#   'lon': 2.450859},
#  1701257410: {'type': 'node',
#   'id': 1701257410,
#   'lat': 48.7889522,
#   'lon': 2.4514346},
#  1701257479: {'type': 'node',
#   'id': 1701257479,
#   'lat': 48.7908108,
#   'lon': 2.4497266},
#  1720645152: {'type': 'node',
#   'id': 1720645152,
#   'lat': 48.8005261,
#   'lon': 2.4492489},
#  1720645253: {'type': 'node',
#   'id': 1720645253,
#   'lat': 48.8013147,
#   'lon': 2.448648},
#  1731763796: {'type': 'node',
#   'id': 1731763796,
#   'lat': 48.8491434,
#   'lon': 2.394693},
#  1731763811: {'type': 'node',
#   'id': 1731763811,
#   'lat': 48.8480952,
#   'lon': 2.3941358},
#  1731763860: {'type': 'node',
#   'id': 1731763860,
#   'lat': 48.8492176,
#   'lon': 2.3945746},
#  1760259453: {'type': 'node',
#   'id': 1760259453,
#   'lat': 48.8647478,
#   'lon': 2.4037041},
#  1762610977: {'type': 'node',
#   'id': 1762610977,
#   'lat': 48.8837969,
#   'lon': 2.3501165,
#   'tags': {'name': 'Barbès - Rochechouart',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'subway': 'yes'}},
#  1763424864: {'type': 'node',
#   'id': 1763424864,
#   'lat': 48.8959108,
#   'lon': 2.4272904},
#  1763424891: {'type': 'node',
#   'id': 1763424891,
#   'lat': 48.8956683,
#   'lon': 2.4264817},
#  1763425044: {'type': 'node',
#   'id': 1763425044,
#   'lat': 48.8937908,
#   'lon': 2.4160191},
#  1763425131: {'type': 'node',
#   'id': 1763425131,
#   'lat': 48.896163,
#   'lon': 2.4279622},
#  1771597590: {'type': 'node',
#   'id': 1771597590,
#   'lat': 48.8529381,
#   'lon': 2.4074878},
#  1771599357: {'type': 'node',
#   'id': 1771599357,
#   'lat': 48.8532369,
#   'lon': 2.4091192},
#  1771632702: {'type': 'node',
#   'id': 1771632702,
#   'lat': 48.9036072,
#   'lon': 2.4492316},
#  1771632714: {'type': 'node',
#   'id': 1771632714,
#   'lat': 48.9036083,
#   'lon': 2.4492669},
#  1771632717: {'type': 'node',
#   'id': 1771632717,
#   'lat': 48.9060421,
#   'lon': 2.4491806},
#  1771632724: {'type': 'node',
#   'id': 1771632724,
#   'lat': 48.9060505,
#   'lon': 2.4492007,
#   'tags': {'STIF:zone': '1',
#    'layer': '-2',
#    'name': 'Bobigny - Pablo Picasso',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:FR:RATP': '2010',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro'}},
#  1771632727: {'type': 'node',
#   'id': 1771632727,
#   'lat': 48.9051938,
#   'lon': 2.4492068,
#   'tags': {'railway': 'switch'}},
#  1771632728: {'type': 'node',
#   'id': 1771632728,
#   'lat': 48.9067601,
#   'lon': 2.449197,
#   'tags': {'railway': 'signal', 'railway:signal:direction': 'backward'}},
#  1771632734: {'type': 'node',
#   'id': 1771632734,
#   'lat': 48.9067011,
#   'lon': 2.449177},
#  1771632740: {'type': 'node',
#   'id': 1771632740,
#   'lat': 48.9060421,
#   'lon': 2.4492845},
#  1771632748: {'type': 'node',
#   'id': 1771632748,
#   'lat': 48.9033375,
#   'lon': 2.4492676},
#  1771632750: {'type': 'node',
#   'id': 1771632750,
#   'lat': 48.9067611,
#   'lon': 2.4492353,
#   'tags': {'railway': 'signal', 'railway:signal:direction': 'forward'}},
#  1771632756: {'type': 'node',
#   'id': 1771632756,
#   'lat': 48.9033384,
#   'lon': 2.4492281},
#  1778063992: {'type': 'node',
#   'id': 1778063992,
#   'lat': 48.8646079,
#   'lon': 2.4091309},
#  1778063993: {'type': 'node',
#   'id': 1778063993,
#   'lat': 48.8647006,
#   'lon': 2.4096579},
#  1778063995: {'type': 'node',
#   'id': 1778063995,
#   'lat': 48.8650342,
#   'lon': 2.4112943},
#  1780486821: {'type': 'node',
#   'id': 1780486821,
#   'lat': 48.8973976,
#   'lon': 2.3448521,
#   'tags': {'STIF:zone': '1',
#    'name': 'Porte de Clignancourt',
#    'operator': 'RATP',
#    'public_transport': 'stop_position',
#    'railway': 'station',
#    'ref:FR:FANTOIR': '75118S435C',
#    'ref:FR:RATP': '1726',
#    'ref:FR:STIF': '22141',
#    'source': 'STIF - 12/2016',
#    'station': 'subway',
#    'subway': 'yes',
#    'type:RATP': 'metro',
#    'wheelchair': 'no',
#    'wikidata': 'Q1969480',
#    'wikipedia': 'fr:Porte de Clignancourt (métro de Paris)'}},
#  1785783405: {'type': 'node',
#   'id': 1785783405,
#   'lat': 48.8406723,
#   'lon': 2.3051648},
#  1786279637: {'type': 'node',
#   'id': 1786279637,
#   'lat': 48.8773313,
#   'lon': 2.349824},
#  1794274662: {'type': 'node',
#   'id': 1794274662,
#   'lat': 48.8546063,
#   'lon': 2.4168575},
#  1811104018: {'type': 'node',
#   'id': 1811104018,
#   'lat': 48.7993577,
#   'lon': 2.3662174},
#  1811104028: {'type': 'node',
#   'id': 1811104028,
#   'lat': 48.7996354,
#   'lon': 2.365816},
#  1811104031: {'type': 'node',
#   'id': 1811104031,
#   'lat': 48.7996914,
#   'lon': 2.3657374},
#  1811104034: {'type': 'node',
#   'id': 1811104034,
#   'lat': 48.7997466,
#   'lon': 2.365663},
#  1811104037: {'type': 'node',
#   'id': 1811104037,
#   'lat': 48.7999474,
#   'lon': 2.3654453},
#  1811104041: {'type': 'node',
#   'id': 1811104041,
#   'lat': 48.8001894,
#   'lon': 2.3653023},
#  1811104046: {'type': 'node',
#   'id': 1811104046,
#   'lat': 48.8004144,
#   'lon': 2.3652306},
#  1811104049: {'type': 'node',
#   'id': 1811104049,
#   'lat': 48.8016759,
#   'lon': 2.3648692},
#  1811214808: {'type': 'node',
#   'id': 1811214808,
#   'lat': 48.7981449,
#   'lon': 2.3675845},
#  1811214809: {'type': 'node',
#   'id': 1811214809,
#   'lat': 48.7986529,
#   'lon': 2.367185},
#  1813629249: {'type': 'node',
#   'id': 1813629249,
#   'lat': 48.8461543,
#   'lon': 2.3554602},
#  1829447189: {'type': 'node',
#   'id': 1829447189,
#   'lat': 48.8626946,
#   'lon': 2.3353566},
#  1840030293: {'type': 'node',
#   'id': 1840030293,
#   'lat': 48.8815499,
#   'lon': 2.3513465,
#   'tags': {'button_operated': 'no',
#    'crossing': 'traffic_signals',
#    'crossing:island': 'yes',
#    'crossing_ref': 'zebra',
#    'highway': 'crossing',
#    'survey:date': '2017-07-04',
#    'tactile_paving': 'yes',
#    'traffic_signals:sound': 'no',
#    'traffic_signals:vibration': 'no'}},
#  1841593379: {'type': 'node',
#   'id': 1841593379,
#   'lat': 48.8615682,
#   'lon': 2.3455783},
#  1841785694: {'type': 'node',
#   'id': 1841785694,
#   'lat': 48.9069932,
#   'lon': 2.3022632},
#  1841785700: {'type': 'node',
#   'id': 1841785700,
#   'lat': 48.9082647,
#   'lon': 2.3000401},
#  ...}

# %%
import networkx as nx

def create_route_graph(route_elements, node_elements):
    """
    Creates a graph of routes with stop nodes and edges between consecutive stops.
    Parameters:
    route_elements (list): A list of route elements containing 'members' and 'tags'.
    node_elements (dict): A dictionary of node elements with their IDs as keys.
    Returns:
    nx.Graph: A NetworkX graph object representing the routes and stop nodes.
    """
    # Create a graph object
    G = nx.Graph()

    for route in route_elements:
        stop_nodes = [member for member in route['members'] if 'stop' in member['role']]
        
        # Add nodes to the graph
        for node in stop_nodes:
            ref = node['ref']
            if ref in node_elements:
                node_data = node_elements[ref]
                name = node_data['tags'].get('name', str(ref))
                colour = route['tags'].get('colour', '#808080')  # Default gray color if no color is defined
                
                G.add_node(ref, pos=(node_data['lon'], node_data['lat']), name=name, colour=colour)
        
        # Add edges between consecutive stop nodes
        for i in range(len(stop_nodes) - 1):
            G.add_edge(stop_nodes[i]['ref'], stop_nodes[i + 1]['ref'])
    
    return G

# %%
import matplotlib.pyplot as plt

def visualize_graph(G, title):
    """
    Visualizes the graph with nodes and edges.
    Parameters:
    G (nx.Graph): A NetworkX graph object representing the routes and stop nodes.
    Returns:
    None: Displays a plot of the graph.
    """
    # Set the plot size
    plt.figure(figsize=(15, 8))  # Adjust the width and height as needed

    # Draw the graph with nodes and edges
    pos = nx.get_node_attributes(G, 'pos')
    node_labels = nx.get_node_attributes(G, 'name')
    node_colours = list(nx.get_node_attributes(G, 'colour').values())
    nx.draw(G, pos, with_labels=True, labels=node_labels, node_size=100, node_color=node_colours, font_size=8)
    nx.draw_networkx_edges(G, pos, edge_color='gray', alpha=0.7)
    plt.title(title)
    plt.show()

# Create the graph for the Hamburg subway system
subway_paris_G = create_route_graph(route_elements, node_elements)

# Visualize the graph with a title
visualize_graph(subway_paris_G, 'Paris Subway System')

# %%
import folium

def visualize_graph_on_folium(G, title, map_center=(48.8566, 2.3522), zoom_start=12):
    """
    Visualizes a NetworkX graph on an interactive Folium map.
    Parameters:
    G (nx.Graph): A NetworkX graph object representing the subway network.
    title (str): Title for the map.
    map_center (tuple): Latitude and longitude for centering the map.
    zoom_start (int): Initial zoom level for the map.
    Returns:
    folium.Map: A Folium map object with the graph plotted.
    """
    # Create a Folium map centered on the specified coordinates
    subway_map = folium.Map(location=map_center, zoom_start=zoom_start)
    
    # Get positions and attributes from the graph
    pos = nx.get_node_attributes(G, 'pos')  # Node positions
    node_colours = nx.get_node_attributes(G, 'colour')  # Node colors
    node_names = nx.get_node_attributes(G, 'name')  # Node names
    
    # Add nodes as markers
    for node, coords in pos.items():
        name = node_names.get(node, "Unnamed Station")
        colour = node_colours.get(node, "#000000")  # Default black if no color specified
        folium.CircleMarker(
            location=(coords[1], coords[0]),  # Folium uses (lat, lon)
            radius=5,
            color=colour,
            fill=True,
            fill_opacity=0.7,
            popup=folium.Popup(name, max_width=300)
        ).add_to(subway_map)
    
    # Add edges as polylines
    for edge in G.edges():
        coord1 = pos[edge[0]]
        coord2 = pos[edge[1]]
        colour = node_colours.get(edge[0], "gray")  # Use the color of the first node in the edge
        folium.PolyLine(
            locations=[(coord1[1], coord1[0]), (coord2[1], coord2[0])],  # Folium uses (lat, lon)
            color=colour,
            weight=2,
            opacity=0.6
        ).add_to(subway_map)
    
    # Add a title to the map (via a custom HTML overlay)
    title_html = f'''
         <h3 align="center" style="font-size:16px"><b>{title}</b></h3>
         '''
    subway_map.get_root().html.add_child(folium.Element(title_html))
    
    return subway_map

# Create the Folium map
paris_subway_map = visualize_graph_on_folium(subway_paris_G, "Paris Subway Network")

# Save the map to an HTML file
paris_subway_map.save("paris_subway_network.html")
print("Map saved as 'paris_subway_network.html'!")

paris_subway_map
# Out:
# Map saved as 'paris_subway_network.html'!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1219798f07ecf8703a203186d6ebb4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#          &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Paris Subway Network&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1219798f07ecf8703a203186d6ebb4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1219798f07ecf8703a203186d6ebb4e = L.map(
#                 &quot;map_f1219798f07ecf8703a203186d6ebb4e&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d070bf616802006b578785754289e521 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d070bf616802006b578785754289e521.addTo(map_f1219798f07ecf8703a203186d6ebb4e);
#
#
#             var circle_marker_ec1e99130f2de47c7d4a1611f1d32fb2 = L.circleMarker(
#                 [48.7688389, 2.4642872],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d282be&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d282be&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f1219798f07ecf8703a203186d6ebb4e);
#
#
#         var popup_96a5123108a0aa244624d6b72616b6ee = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d9ad3869f7d9b2f758feeb05a4ec3df6 = $(`&lt;div id=&quot;html_d9ad3869f7d9b2f758feeb05a4ec3df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pointe du Lac&lt;/div&gt;`)[0];
#                 popup_96a5123108a0aa244624d6b72616b6ee.setContent(html_d9ad3869f7d9b2f758feeb05a4ec3df6);
#
#
#
#         circle_marker_ec1e99130f2de47c7d4a1611f1d32fb2.bindPopup(popup_96a5123108a0aa244624d6b72616b6ee)
#         ;
#
#
#
#
#             var circle_marker_fcd9d9405593a91c3109d6913cfd1542 = L.circleMarker(
#                 [48.7803755, 2.4594358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d282be&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d282be&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f1219798f07ecf8703a203186d6ebb4e);
#
#
#         var popup_8091feb9572dd7ac4c0a39635e37c587 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_26437785bead4cde11bd972a88e8be59 = $(`&lt;div id=&quot;html_26437785bead4cde11bd972a88e8be59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Créteil-Préfecture&lt;/div&gt;`)[0];
#                 popup_8091feb9572dd7ac4c0a39635e37c587.setContent(html_26437785bead4cde11bd972a88e8be59);
#
#
#
#         circle_marker_fcd9d9405593a91c3109d6913cfd1542.bindPopup(popup_8091feb9572dd7ac4c0a39635e37c587)
#         ;
#
#
#
#
#             var circle_marker_d375dc26f4342f8fb19e610571f71d25 = L.circleMarker(
#                 [48.7902849, 2.4502669],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d282be&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d282be&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f1219798f07ecf8703a203186d6ebb4e);
#
#
#         var popup_6975912ca88f67bdda2d16483ee307e2 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c687b26bad9e0669b191d87223561eba = $(`&lt;div id=&quot;html_c687b26bad9e0669b191d87223561eba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Créteil-Université&lt;/div&gt;`)[0];
#                 popup_6975912ca88f67bdda2d16483ee307e2.setContent(html_c687b26bad9e0669b191d87223561eba);
#
#
#
#         circle_marker_d375dc26f4342f8fb19e610571f71d25.bindPopup(popup_6975912ca88f67bdda2d16483ee307e2)
#         ;
#
#
#
#
#             var circle_marker_5851e70a230dfb1007fa88a768466943 = L.circleMarker(
#                 [48.7970201, 2.449587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot
