# %%
import requests
import folium

def extract_osm_geodata(query):
    """
    Extracts geodata from OpenStreetMap using the Overpass API.
    Parameters:
    query (str): The Overpass API query string to execute.
    Returns:
    dict: GeoJSON data retrieved by the query.
    """
    # Define the Overpass API URL
    overpass_url = "https://lz4.overpass-api.de/api/interpreter"
    
    # Define the parameters for the GET request
    params = {'data': query}
    
    # Send a GET request to the Overpass API with the query
    response = requests.get(overpass_url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        response.raise_for_status()

# %%
# Query to extract subway stations in Berlin
query = """
[out:json];
area[name="Berlin"]->.searchArea;
relation["route"~"subway"](area.searchArea);
out meta;
>;
out body;
"""
subway_berlin_data = extract_osm_geodata(query)

# %%
def extract_route_elements(osm_data):
    """
    Extracts route elements from the OpenStreetMap data response.
    Parameters:
    osm_data (dict): The JSON response data from the Overpass API.
    Returns:
    list: A list of route elements containing 'tags' with 'route' information.
    """
    route_elements = [element for element in osm_data['elements'] if 'tags' in element and 'route' in element['tags']]
    return route_elements

# Call the function to extract route elements from the OpenStreetMap data for London's subway
route_elements =  extract_route_elements(subway_berlin_data)

# Visualize the route of the list
route_elements[0]
# Out:
# {'type': 'relation',
#  'id': 2227743,
#  'timestamp': '2024-11-12T21:30:40Z',
#  'version': 94,
#  'changeset': 159069189,
#  'user': 'osm-pt-account 😎',
#  'uid': 12419182,
#  'members': [{'type': 'node', 'ref': 3856100107, 'role': 'stop'},
#   {'type': 'way', 'ref': 86379623, 'role': 'platform'},
#   {'type': 'node', 'ref': 7057285551, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138760, 'role': 'platform'},
#   {'type': 'node', 'ref': 7057285550, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138761, 'role': 'platform'},
#   {'type': 'node', 'ref': 8087330616, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138762, 'role': 'platform'},
#   {'type': 'node', 'ref': 7974955393, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138763, 'role': 'platform'},
#   {'type': 'node', 'ref': 8196661136, 'role': 'stop'},
#   {'type': 'way', 'ref': 881301598, 'role': 'platform'},
#   {'type': 'node', 'ref': 2094266776, 'role': 'stop'},
#   {'type': 'way', 'ref': 194973329, 'role': 'platform'},
#   {'type': 'node', 'ref': 55189765, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138764, 'role': 'platform'},
#   {'type': 'node', 'ref': 3846589196, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138765, 'role': 'platform'},
#   {'type': 'node', 'ref': 3169023533, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138766, 'role': 'platform'},
#   {'type': 'node', 'ref': 3876349057, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138767, 'role': 'platform'},
#   {'type': 'node', 'ref': 3935369910, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138768, 'role': 'platform'},
#   {'type': 'node', 'ref': 710904931, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138769, 'role': 'platform'},
#   {'type': 'node', 'ref': 3933477400, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138770, 'role': 'platform'},
#   {'type': 'node', 'ref': 1784905015, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138771, 'role': 'platform'},
#   {'type': 'node', 'ref': 3926745600, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138772, 'role': 'platform'},
#   {'type': 'node', 'ref': 4635829120, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138773, 'role': 'platform'},
#   {'type': 'node', 'ref': 557841454, 'role': 'stop'},
#   {'type': 'way', 'ref': 43888161, 'role': 'platform'},
#   {'type': 'node', 'ref': 557827057, 'role': 'stop'},
#   {'type': 'relation', 'ref': 7596078, 'role': 'platform'},
#   {'type': 'node', 'ref': 1117011601, 'role': 'stop'},
#   {'type': 'relation', 'ref': 7591519, 'role': 'platform'},
#   {'type': 'node', 'ref': 53274722, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138775, 'role': 'platform'},
#   {'type': 'node', 'ref': 53274725, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138776, 'role': 'platform'},
#   {'type': 'node', 'ref': 52692783, 'role': 'stop'},
#   {'type': 'relation', 'ref': 5837145, 'role': 'platform'},
#   {'type': 'node', 'ref': 4635829119, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138778, 'role': 'platform'},
#   {'type': 'node', 'ref': 4635829118, 'role': 'stop'},
#   {'type': 'relation', 'ref': 18138779, 'role': 'platform'},
#   {'type': 'node', 'ref': 52684988, 'role': 'stop_exit_only'},
#   {'type': 'way', 'ref': 87232575, 'role': 'platform_exit_only'},
#   {'type': 'way', 'ref': 871673626, 'role': ''},
#   {'type': 'way', 'ref': 421618237, 'role': ''},
#   {'type': 'way', 'ref': 421618232, 'role': ''},
#   {'type': 'way', 'ref': 360588975, 'role': ''},
#   {'type': 'way', 'ref': 421618236, 'role': ''},
#   {'type': 'way', 'ref': 248099627, 'role': ''},
#   {'type': 'way', 'ref': 942849696, 'role': ''},
#   {'type': 'way', 'ref': 942849695, 'role': ''},
#   {'type': 'way', 'ref': 248099628, 'role': ''},
#   {'type': 'way', 'ref': 4699210, 'role': ''},
#   {'type': 'way', 'ref': 807043967, 'role': ''},
#   {'type': 'way', 'ref': 29030957, 'role': ''},
#   {'type': 'way', 'ref': 384320732, 'role': ''},
#   {'type': 'way', 'ref': 438860780, 'role': ''},
#   {'type': 'way', 'ref': 317769294, 'role': ''},
#   {'type': 'way', 'ref': 381471709, 'role': ''},
#   {'type': 'way', 'ref': 396744562, 'role': ''},
#   {'type': 'way', 'ref': 172093540, 'role': ''},
#   {'type': 'way', 'ref': 464757323, 'role': ''},
#   {'type': 'way', 'ref': 464757334, 'role': ''},
#   {'type': 'way', 'ref': 438957596, 'role': ''},
#   {'type': 'way', 'ref': 438957586, 'role': ''},
#   {'type': 'way', 'ref': 43887969, 'role': ''},
#   {'type': 'way', 'ref': 391356361, 'role': ''},
#   {'type': 'way', 'ref': 152796065, 'role': ''},
#   {'type': 'way', 'ref': 43887965, 'role': ''},
#   {'type': 'way', 'ref': 43887963, 'role': ''},
#   {'type': 'way', 'ref': 27502899, 'role': ''},
#   {'type': 'way', 'ref': 27526916, 'role': ''},
#   {'type': 'way', 'ref': 520751016, 'role': ''},
#   {'type': 'way', 'ref': 279092738, 'role': ''},
#   {'type': 'way', 'ref': 221009437, 'role': ''},
#   {'type': 'way', 'ref': 36784506, 'role': ''},
#   {'type': 'way', 'ref': 36784507, 'role': ''},
#   {'type': 'way', 'ref': 396007082, 'role': ''},
#   {'type': 'way', 'ref': 396007084, 'role': ''},
#   {'type': 'way', 'ref': 550965671, 'role': ''},
#   {'type': 'way', 'ref': 42126837, 'role': ''},
#   {'type': 'way', 'ref': 40643932, 'role': ''},
#   {'type': 'way', 'ref': 40643933, 'role': ''},
#   {'type': 'way', 'ref': 518326502, 'role': ''},
#   {'type': 'way', 'ref': 140166842, 'role': ''},
#   {'type': 'way', 'ref': 140166841, 'role': ''},
#   {'type': 'way', 'ref': 290324137, 'role': ''},
#   {'type': 'way', 'ref': 321008735, 'role': ''},
#   {'type': 'way', 'ref': 290323894, 'role': ''},
#   {'type': 'way', 'ref': 290323869, 'role': ''},
#   {'type': 'way', 'ref': 807043966, 'role': ''}],
#  'tags': {'colour': '#7E5330',
#   'from': 'U Hauptbahnhof',
#   'interval': '5',
#   'name': 'U5: U Hauptbahnhof => U Hönow',
#   'network': 'Verkehrsverbund Berlin-Brandenburg',
#   'network:metro': 'u-bahn',
#   'network:short': 'VBB',
#   'network:wikidata': 'Q315451',
#   'network:wikipedia': 'de:Verkehrsverbund Berlin-Brandenburg',
#   'operator': 'Berliner Verkehrsbetriebe',
#   'operator:short': 'BVG',
#   'operator:wikidata': 'Q99633',
#   'operator:wikipedia': 'de:Berliner Verkehrsbetriebe',
#   'public_transport:version': '2',
#   'ref': 'U5',
#   'route': 'subway',
#   'service_times': 'Mo-Fr 00:00-00:30,04:00-00:30; Sa,Su,PH 00:00-24:00',
#   'to': 'U Hönow',
#   'type': 'route',
#   'wikidata': 'Q99711',
#   'wikipedia': 'de:U-Bahn-Linie U5 (Berlin)'}}

# %%
def extract_node_elements(osm_data):
    """
    Extracts node elements from the OpenStreetMap data response.
    Parameters:
    osm_data (dict): The JSON response data from the Overpass API.
    Returns:
    dict: A dictionary where the keys are node IDs and the values are the corresponding node elements.
    """
    node_elements = {element['id']: element for element in osm_data['elements'] if element['type'] == 'node'}
    return node_elements

# Call the function to extract node elements from the OpenStreetMap data for Hamburg's subway
node_elements = extract_node_elements(subway_berlin_data)

# Visualize the node_elements list
node_elements
# Out:
# {26736209: {'type': 'node',
#   'id': 26736209,
#   'lat': 52.5020539,
#   'lon': 13.3078177},
#  26749215: {'type': 'node',
#   'id': 26749215,
#   'lat': 52.5342945,
#   'lon': 13.3784251},
#  26925638: {'type': 'node',
#   'id': 26925638,
#   'lat': 52.4503065,
#   'lon': 13.2690559,
#   'tags': {'description': 'U Oskar-Helene-Heim, Gleis 2',
#    'name': 'Oskar-Helene-Heim',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '234202',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h234202'}},
#  26925639: {'type': 'node',
#   'id': 26925639,
#   'lat': 52.4502111,
#   'lon': 13.2710344},
#  26925640: {'type': 'node',
#   'id': 26925640,
#   'lat': 52.4498443,
#   'lon': 13.2767077},
#  26925641: {'type': 'node',
#   'id': 26925641,
#   'lat': 52.4498634,
#   'lon': 13.2776896},
#  26925642: {'type': 'node',
#   'id': 26925642,
#   'lat': 52.4499902,
#   'lon': 13.2787338},
#  26925643: {'type': 'node',
#   'id': 26925643,
#   'lat': 52.4501307,
#   'lon': 13.2793803},
#  26925644: {'type': 'node',
#   'id': 26925644,
#   'lat': 52.4510332,
#   'lon': 13.281851,
#   'tags': {'name': 'Freie Universität (Thielplatz)',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '234102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h234102'}},
#  27251457: {'type': 'node',
#   'id': 27251457,
#   'lat': 52.4523319,
#   'lon': 13.2847427},
#  27251458: {'type': 'node',
#   'id': 27251458,
#   'lat': 52.4527594,
#   'lon': 13.2854394},
#  27251459: {'type': 'node',
#   'id': 27251459,
#   'lat': 52.4530836,
#   'lon': 13.2858384},
#  27251460: {'type': 'node',
#   'id': 27251460,
#   'lat': 52.457393,
#   'lon': 13.2897787},
#  27253801: {'type': 'node',
#   'id': 27253801,
#   'lat': 52.4506531,
#   'lon': 13.2809517},
#  27276972: {'type': 'node',
#   'id': 27276972,
#   'lat': 52.4507455,
#   'lon': 13.2628066},
#  27276973: {'type': 'node',
#   'id': 27276973,
#   'lat': 52.4508269,
#   'lon': 13.2587049},
#  27276975: {'type': 'node',
#   'id': 27276975,
#   'lat': 52.4506555,
#   'lon': 13.2567917},
#  27276976: {'type': 'node',
#   'id': 27276976,
#   'lat': 52.4502318,
#   'lon': 13.2545133},
#  27276977: {'type': 'node',
#   'id': 27276977,
#   'lat': 52.4490658,
#   'lon': 13.2509037},
#  27276979: {'type': 'node',
#   'id': 27276979,
#   'lat': 52.4475999,
#   'lon': 13.2479915},
#  27276980: {'type': 'node',
#   'id': 27276980,
#   'lat': 52.445764,
#   'lon': 13.2452105},
#  27276982: {'type': 'node',
#   'id': 27276982,
#   'lat': 52.4443813,
#   'lon': 13.2429403,
#   'tags': {'railway': 'switch'}},
#  27409001: {'type': 'node',
#   'id': 27409001,
#   'lat': 52.5129479,
#   'lon': 13.3050375,
#   'tags': {'ele': '38.9'}},
#  27537336: {'type': 'node',
#   'id': 27537336,
#   'lat': 52.4969474,
#   'lon': 13.3685244},
#  27537337: {'type': 'node',
#   'id': 27537337,
#   'lat': 52.496997,
#   'lon': 13.3719094},
#  27537339: {'type': 'node',
#   'id': 27537339,
#   'lat': 52.4973994,
#   'lon': 13.3733209},
#  27537340: {'type': 'node',
#   'id': 27537340,
#   'lat': 52.4978598,
#   'lon': 13.3736623},
#  27586257: {'type': 'node',
#   'id': 27586257,
#   'lat': 52.5250982,
#   'lon': 13.2433588},
#  27586258: {'type': 'node',
#   'id': 27586258,
#   'lat': 52.5247923,
#   'lon': 13.2440581},
#  27586260: {'type': 'node',
#   'id': 27586260,
#   'lat': 52.5243823,
#   'lon': 13.244585},
#  27586261: {'type': 'node',
#   'id': 27586261,
#   'lat': 52.5241246,
#   'lon': 13.2447826},
#  27586271: {'type': 'node',
#   'id': 27586271,
#   'lat': 52.5234729,
#   'lon': 13.2450465},
#  27586272: {'type': 'node',
#   'id': 27586272,
#   'lat': 52.5229874,
#   'lon': 13.2452516},
#  27586275: {'type': 'node',
#   'id': 27586275,
#   'lat': 52.5225316,
#   'lon': 13.245564},
#  27587029: {'type': 'node',
#   'id': 27587029,
#   'lat': 52.5202529,
#   'lon': 13.247925},
#  27587045: {'type': 'node',
#   'id': 27587045,
#   'lat': 52.51605,
#   'lon': 13.2534137},
#  27785725: {'type': 'node',
#   'id': 27785725,
#   'lat': 52.5003424,
#   'lon': 13.3499521},
#  27790533: {'type': 'node',
#   'id': 27790533,
#   'lat': 52.4995962,
#   'lon': 13.3699831},
#  28114273: {'type': 'node',
#   'id': 28114273,
#   'lat': 52.4997955,
#   'lon': 13.3525281},
#  29045592: {'type': 'node',
#   'id': 29045592,
#   'lat': 52.5320987,
#   'lon': 13.341235,
#   'tags': {'description': 'U Birkenstraße, Gleis 1',
#    'name': 'Birkenstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292601',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292601'}},
#  29045594: {'type': 'node',
#   'id': 29045594,
#   'lat': 52.5364786,
#   'lon': 13.3423432,
#   'tags': {'description': 'U Westhafen, Gleis 1',
#    'name': 'Westhafen',
#    'name:BVG': 'S+U Westhafen',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292501'}},
#  29045597: {'type': 'node',
#   'id': 29045597,
#   'lat': 52.5421459,
#   'lon': 13.3494883,
#   'tags': {'description': 'U Amrumer Straße, Gleis 1',
#    'name': 'Amrumer Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292401',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292401'}},
#  29045598: {'type': 'node',
#   'id': 29045598,
#   'lat': 52.5436117,
#   'lon': 13.3537504},
#  29045599: {'type': 'node',
#   'id': 29045599,
#   'lat': 52.545135,
#   'lon': 13.3571449},
#  29045601: {'type': 'node',
#   'id': 29045601,
#   'lat': 52.5441212,
#   'lon': 13.355001},
#  29046165: {'type': 'node',
#   'id': 29046165,
#   'lat': 52.551389,
#   'lon': 13.3672268,
#   'tags': {'description': 'U Nauener Platz, Gleis 2',
#    'line': 'U9',
#    'name': 'Nauener Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292202',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292202'}},
#  29046166: {'type': 'node',
#   'id': 29046166,
#   'lat': 52.5497647,
#   'lon': 13.3645043},
#  29046167: {'type': 'node',
#   'id': 29046167,
#   'lat': 52.557134,
#   'lon': 13.373322,
#   'tags': {'line': 'U9',
#    'name': 'Osloer Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292102'}},
#  29046169: {'type': 'node', 'id': 29046169, 'lat': 52.5539, 'lon': 13.3709215},
#  29046444: {'type': 'node',
#   'id': 29046444,
#   'lat': 52.5264047,
#   'lon': 13.3414103,
#   'tags': {'line': 'U9',
#    'name': 'Turmstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292702',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292702'}},
#  29046445: {'type': 'node',
#   'id': 29046445,
#   'lat': 52.5234683,
#   'lon': 13.3410459},
#  29046446: {'type': 'node',
#   'id': 29046446,
#   'lat': 52.5177461,
#   'lon': 13.342012,
#   'tags': {'description': 'U Hansaplatz, Gleis 1',
#    'line': 'U9',
#    'name': 'Hansaplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '292801',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h292801'}},
#  29046447: {'type': 'node',
#   'id': 29046447,
#   'lat': 52.5154949,
#   'lon': 13.342058},
#  29046448: {'type': 'node',
#   'id': 29046448,
#   'lat': 52.5125118,
#   'lon': 13.3396128},
#  29046967: {'type': 'node',
#   'id': 29046967,
#   'lat': 52.505572,
#   'lon': 13.3318547},
#  29046973: {'type': 'node',
#   'id': 29046973,
#   'lat': 52.4957215,
#   'lon': 13.3308583},
#  29046982: {'type': 'node',
#   'id': 29046982,
#   'lat': 52.500015,
#   'lon': 13.3308947},
#  29046985: {'type': 'node',
#   'id': 29046985,
#   'lat': 52.4843028,
#   'lon': 13.3311415},
#  29046987: {'type': 'node',
#   'id': 29046987,
#   'lat': 52.4803281,
#   'lon': 13.3287645},
#  29046990: {'type': 'node',
#   'id': 29046990,
#   'lat': 52.4774637,
#   'lon': 13.3284196,
#   'tags': {'line': 'U9',
#    'name': 'Bundesplatz',
#    'name:BVG': 'S+U Bundesplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '293401',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h293401'}},
#  29046994: {'type': 'node',
#   'id': 29046994,
#   'lat': 52.4738856,
#   'lon': 13.3283856},
#  29047035: {'type': 'node',
#   'id': 29047035,
#   'lat': 52.470351,
#   'lon': 13.3282776},
#  29047042: {'type': 'node',
#   'id': 29047042,
#   'lat': 52.4717109,
#   'lon': 13.3286106,
#   'tags': {'line': 'U9',
#    'name': 'Friedrich-Wilhelm-Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '293501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h293501'}},
#  29047044: {'type': 'node',
#   'id': 29047044,
#   'lat': 52.4637071,
#   'lon': 13.3273843},
#  29047050: {'type': 'node',
#   'id': 29047050,
#   'lat': 52.4833717,
#   'lon': 13.3307639},
#  29057786: {'type': 'node',
#   'id': 29057786,
#   'lat': 52.5600134,
#   'lon': 13.334889,
#   'tags': {'description': 'U Afrikanische Straße, Gleis 1',
#    'name': 'Afrikanische Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '262701',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h262701'}},
#  29057787: {'type': 'node',
#   'id': 29057787,
#   'lat': 52.5513272,
#   'lon': 13.3504552},
#  29058096: {'type': 'node',
#   'id': 29058096,
#   'lat': 52.5401117,
#   'lon': 13.3700088},
#  29058100: {'type': 'node',
#   'id': 29058100,
#   'lat': 52.5256031,
#   'lon': 13.3872745,
#   'tags': {'name': 'Oranienburger Tor',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '263501',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h263501'}},
#  29058101: {'type': 'node',
#   'id': 29058101,
#   'lat': 52.5274554,
#   'lon': 13.3868451},
#  29058258: {'type': 'node',
#   'id': 29058258,
#   'lat': 52.521635,
#   'lon': 13.387997,
#   'tags': {'entrance': 'emergency', 'ref': 'C32'}},
#  29058262: {'type': 'node',
#   'id': 29058262,
#   'lat': 52.498176,
#   'lon': 13.3917244},
#  29058263: {'type': 'node',
#   'id': 29058263,
#   'lat': 52.494366,
#   'lon': 13.388632,
#   'tags': {'name': 'Mehringdamm',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '264101',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h264101'}},
#  29058337: {'type': 'node',
#   'id': 29058337,
#   'lat': 52.4912988,
#   'lon': 13.3868593},
#  29058338: {'type': 'node',
#   'id': 29058338,
#   'lat': 52.4893176,
#   'lon': 13.3862193},
#  29058340: {'type': 'node',
#   'id': 29058340,
#   'lat': 52.482941,
#   'lon': 13.3863861},
#  29058343: {'type': 'node',
#   'id': 29058343,
#   'lat': 52.4699261,
#   'lon': 13.3856773,
#   'tags': {'description': 'U Tempelhof, Gleis 2',
#    'name': 'Tempelhof',
#    'name:BVG': 'S+U Tempelhof',
#    'platforms': '2',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '264402',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h264402'}},
#  29058344: {'type': 'node',
#   'id': 29058344,
#   'lat': 52.4657118,
#   'lon': 13.385737,
#   'tags': {'name': 'Alt-Tempelhof',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '264502',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h264502'}},
#  29123753: {'type': 'node',
#   'id': 29123753,
#   'lat': 52.5103488,
#   'lon': 13.27059},
#  29123755: {'type': 'node',
#   'id': 29123755,
#   'lat': 52.5095558,
#   'lon': 13.2750561},
#  29123757: {'type': 'node',
#   'id': 29123757,
#   'lat': 52.5102053,
#   'lon': 13.2846358},
#  29123759: {'type': 'node',
#   'id': 29123759,
#   'lat': 52.5161694,
#   'lon': 13.2557374},
#  29123760: {'type': 'node',
#   'id': 29123760,
#   'lat': 52.5162791,
#   'lon': 13.25732},
#  29123762: {'type': 'node',
#   'id': 29123762,
#   'lat': 52.5108916,
#   'lon': 13.2958152,
#   'tags': {'name': 'Sophie-Charlotte-Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '224301',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h224301'}},
#  29123768: {'type': 'node',
#   'id': 29123768,
#   'lat': 52.5054172,
#   'lon': 13.3340072},
#  29123769: {'type': 'node',
#   'id': 29123769,
#   'lat': 52.5051279,
#   'lon': 13.3353912},
#  29123772: {'type': 'node',
#   'id': 29123772,
#   'lat': 52.5014914,
#   'lon': 13.3444479},
#  29190890: {'type': 'node',
#   'id': 29190890,
#   'lat': 52.5645265,
#   'lon': 13.3638451,
#   'tags': {'name': 'Franz-Neumann-Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '282801',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h282801'}},
#  29190893: {'type': 'node',
#   'id': 29190893,
#   'lat': 52.5730547,
#   'lon': 13.3594711},
#  29190894: {'type': 'node',
#   'id': 29190894,
#   'lat': 52.5733499,
#   'lon': 13.3586875},
#  29190895: {'type': 'node',
#   'id': 29190895,
#   'lat': 52.574159,
#   'lon': 13.3493359,
#   'tags': {'description': 'U Paracelsus-Bad, Gleis 2',
#    'name': 'Paracelsus-Bad',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '282602',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h282602'}},
#  29190901: {'type': 'node',
#   'id': 29190901,
#   'lat': 52.5538927,
#   'lon': 13.3769867},
#  29190902: {'type': 'node',
#   'id': 29190902,
#   'lat': 52.5533124,
#   'lon': 13.3780589},
#  29190904: {'type': 'node',
#   'id': 29190904,
#   'lat': 52.5526528,
#   'lon': 13.3805068},
#  29190905: {'type': 'node',
#   'id': 29190905,
#   'lat': 52.5512944,
#   'lon': 13.3834279},
#  29190906: {'type': 'node',
#   'id': 29190906,
#   'lat': 52.5493657,
#   'lon': 13.3871421},
#  29190907: {'type': 'node',
#   'id': 29190907,
#   'lat': 52.5488187,
#   'lon': 13.3884238,
#   'tags': {'layer': '-3',
#    'level': '-3',
#    'name': 'Gesundbrunnen',
#    'name:BVG': 'S+U Gesundbrunnen',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '283102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h283102'}},
#  29190908: {'type': 'node',
#   'id': 29190908,
#   'lat': 52.5421132,
#   'lon': 13.3931106,
#   'tags': {'description': 'U Voltastraße, Gleis 2',
#    'name': 'Voltastraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '283202',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h283202'}},
#  29190909: {'type': 'node',
#   'id': 29190909,
#   'lat': 52.5374437,
#   'lon': 13.3967379,
#   'tags': {'description': 'U Bernauer Straße, Gleis 2',
#    'name': 'Bernauer Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '283302',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h283302'}},
#  29190910: {'type': 'node',
#   'id': 29190910,
#   'lat': 52.536391,
#   'lon': 13.3973387},
#  29190911: {'type': 'node',
#   'id': 29190911,
#   'lat': 52.5328827,
#   'lon': 13.3987583,
#   'tags': {'entrance': 'emergency'}},
#  29216568: {'type': 'node',
#   'id': 29216568,
#   'lat': 52.4986121,
#   'lon': 13.4121144},
#  29318897: {'type': 'node',
#   'id': 29318897,
#   'lat': 52.4999215,
#   'lon': 13.3619354,
#   'tags': {'name': 'Kurfürstenstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '212902',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h212902'}},
#  29318898: {'type': 'node',
#   'id': 29318898,
#   'lat': 52.4996011,
#   'lon': 13.3635703},
#  29318899: {'type': 'node',
#   'id': 29318899,
#   'lat': 52.4999561,
#   'lon': 13.3651532},
#  29318900: {'type': 'node',
#   'id': 29318900,
#   'lat': 52.5000178,
#   'lon': 13.3657593},
#  29318901: {'type': 'node',
#   'id': 29318901,
#   'lat': 52.4999122,
#   'lon': 13.3668713},
#  29323940: {'type': 'node',
#   'id': 29323940,
#   'lat': 52.500228,
#   'lon': 13.3742097},
#  29323977: {'type': 'node',
#   'id': 29323977,
#   'lat': 52.5006308,
#   'lon': 13.3740991},
#  29323979: {'type': 'node',
#   'id': 29323979,
#   'lat': 52.5011778,
#   'lon': 13.3741687},
#  29323980: {'type': 'node',
#   'id': 29323980,
#   'lat': 52.5024168,
#   'lon': 13.3744844},
#  29324017: {'type': 'node',
#   'id': 29324017,
#   'lat': 52.5039,
#   'lon': 13.3749525,
#   'tags': {'name': 'Mendelssohn-Bartholdy-Park',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223402',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h223402'}},
#  29324020: {'type': 'node',
#   'id': 29324020,
#   'lat': 52.5055949,
#   'lon': 13.3759017},
#  29492962: {'type': 'node',
#   'id': 29492962,
#   'lat': 52.5651582,
#   'lon': 13.3636857},
#  29494287: {'type': 'node',
#   'id': 29494287,
#   'lat': 52.5135608,
#   'lon': 13.4176486,
#   'tags': {'railway': 'switch', 'railway:switch': 'double_slip'}},
#  29494288: {'type': 'node',
#   'id': 29494288,
#   'lat': 52.510471,
#   'lon': 13.4159741,
#   'tags': {'name': 'Heinrich-Heine-Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '283801',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h283801'}},
#  29494289: {'type': 'node',
#   'id': 29494289,
#   'lat': 52.5036644,
#   'lon': 13.410604,
#   'tags': {'description': 'U Moritzplatz, Gleis 1',
#    'name': 'Moritzplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '283901',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h283901'}},
#  29494292: {'type': 'node',
#   'id': 29494292,
#   'lat': 52.4931022,
#   'lon': 13.4220998,
#   'tags': {'description': 'U Schönleinstraße, Gleis 2',
#    'name': 'Schönleinstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '284102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h284102'}},
#  29494293: {'type': 'node',
#   'id': 29494293,
#   'lat': 52.5262753,
#   'lon': 13.4035396},
#  29494295: {'type': 'node',
#   'id': 29494295,
#   'lat': 52.5249771,
#   'lon': 13.4060891},
#  29494298: {'type': 'node',
#   'id': 29494298,
#   'lat': 52.5186157,
#   'lon': 13.4153226},
#  29494299: {'type': 'node',
#   'id': 29494299,
#   'lat': 52.5174428,
#   'lon': 13.4161026},
#  29494300: {'type': 'node',
#   'id': 29494300,
#   'lat': 52.516783,
#   'lon': 13.417548},
#  29494302: {'type': 'node',
#   'id': 29494302,
#   'lat': 52.4880258,
#   'lon': 13.4250905},
#  29494303: {'type': 'node',
#   'id': 29494303,
#   'lat': 52.4863348,
#   'lon': 13.4242685},
#  29494305: {'type': 'node',
#   'id': 29494305,
#   'lat': 52.4801908,
#   'lon': 13.4253259,
#   'tags': {'description': 'U Boddinstraße, Gleis 2',
#    'name': 'Boddinstraße',
#    'network': 'Verkehrsverbund Berlin-Brandenburg',
#    'network:short': 'VBB',
#    'operator': 'Berliner Verkehrsbetriebe',
#    'operator:short': 'BVG',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '284302',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h284302'}},
#  29494306: {'type': 'node',
#   'id': 29494306,
#   'lat': 52.4729946,
#   'lon': 13.4284168,
#   'tags': {'description': 'U Leinestraße, Gleis 2',
#    'name': 'Leinestraße',
#    'network': 'Verkehrsverbund Berlin-Brandenburg',
#    'network:short': 'VBB',
#    'operator': 'Berliner Verkehrsbetriebe',
#    'operator:short': 'BVG',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '284402',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h284402'}},
#  29494557: {'type': 'node',
#   'id': 29494557,
#   'lat': 52.5290189,
#   'lon': 13.4098939},
#  29494561: {'type': 'node',
#   'id': 29494561,
#   'lat': 52.5312176,
#   'lon': 13.4121802},
#  29494562: {'type': 'node',
#   'id': 29494562,
#   'lat': 52.5335905,
#   'lon': 13.412878},
#  29494563: {'type': 'node',
#   'id': 29494563,
#   'lat': 52.5415356,
#   'lon': 13.4122415,
#   'tags': {'description': 'U Eberswalder Straße, Gleis 2',
#    'name': 'Eberswalder Straße',
#    'name:ja': 'エベルスヴァルダー通り',
#    'old_name': 'U Dimitroffstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '222302',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h222302'}},
#  29494564: {'type': 'node',
#   'id': 29494564,
#   'lat': 52.5475664,
#   'lon': 13.4134023},
#  29494565: {'type': 'node',
#   'id': 29494565,
#   'lat': 52.5547222,
#   'lon': 13.4146687},
#  29494567: {'type': 'node',
#   'id': 29494567,
#   'lat': 52.5574862,
#   'lon': 13.4141108},
#  29495025: {'type': 'node',
#   'id': 29495025,
#   'lat': 52.519891,
#   'lon': 13.413046},
#  29495026: {'type': 'node',
#   'id': 29495026,
#   'lat': 52.5184563,
#   'lon': 13.411604},
#  29495029: {'type': 'node',
#   'id': 29495029,
#   'lat': 52.5172066,
#   'lon': 13.4125273,
#   'tags': {'description': 'U Klosterstraße, Gleis 2',
#    'name': 'Klosterstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '222702',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h222702'}},
#  29495031: {'type': 'node',
#   'id': 29495031,
#   'lat': 52.5148619,
#   'lon': 13.4121936},
#  29495032: {'type': 'node',
#   'id': 29495032,
#   'lat': 52.5127246,
#   'lon': 13.4113621},
#  29495034: {'type': 'node',
#   'id': 29495034,
#   'lat': 52.5123062,
#   'lon': 13.4102013,
#   'tags': {'description': 'U Märkisches Museum, Gleis 2',
#    'name': 'Märkisches Museum',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '222802',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h222802'}},
#  29495037: {'type': 'node',
#   'id': 29495037,
#   'lat': 52.511286,
#   'lon': 13.4029249},
#  29495038: {'type': 'node',
#   'id': 29495038,
#   'lat': 52.5114253,
#   'lon': 13.4016683},
#  29495040: {'type': 'node',
#   'id': 29495040,
#   'lat': 52.5131504,
#   'lon': 13.396912},
#  29495041: {'type': 'node',
#   'id': 29495041,
#   'lat': 52.5133073,
#   'lon': 13.3955568,
#   'tags': {'description': 'U Hausvogteiplatz, Gleis 2',
#    'name': 'Hausvogteiplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223002',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h223002'}},
#  29495047: {'type': 'node',
#   'id': 29495047,
#   'lat': 52.511813,
#   'lon': 13.3858515,
#   'tags': {'description': 'U Mohrenstraße, Gleis',
#    'name': 'Mohrenstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223202',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h223202'}},
#  29495049: {'type': 'node',
#   'id': 29495049,
#   'lat': 52.509134,
#   'lon': 13.3783037,
#   'tags': {'name': 'Potsdamer Platz',
#    'name:BVG': 'S+U Potsdamer Platz [U2]',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223302',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h223302'}},
#  29495891: {'type': 'node',
#   'id': 29495891,
#   'lat': 52.4975794,
#   'lon': 13.3631731,
#   'tags': {'description': 'U Bülowstraße, Gleis 2',
#    'name': 'Bülowstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223602',
#    'subway': 'yes',
#    'surveillance': 'outdoor',
#    'website': 'https://qr.bvg.de/h223602',
#    'wikidata': 'Q374881',
#    'wikipedia': 'de:U-Bahnhof Bülowstraße'}},
#  29496897: {'type': 'node',
#   'id': 29496897,
#   'lat': 52.5009322,
#   'lon': 13.3578988},
#  29496903: {'type': 'node',
#   'id': 29496903,
#   'lat': 52.4952212,
#   'lon': 13.3418854},
#  29690313: {'type': 'node',
#   'id': 29690313,
#   'lat': 52.5631787,
#   'lon': 13.3271376,
#   'tags': {'description': 'U Kurt-Schumacher Platz, Gleis 1',
#    'name': 'Kurt-Schumacher-Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '262601',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h262601'}},
#  29786293: {'type': 'node',
#   'id': 29786293,
#   'lat': 52.4647136,
#   'lon': 13.2975024},
#  29786294: {'type': 'node',
#   'id': 29786294,
#   'lat': 52.4631058,
#   'lon': 13.2934686},
#  29786299: {'type': 'node',
#   'id': 29786299,
#   'lat': 52.4673898,
#   'lon': 13.309643},
#  29786300: {'type': 'node',
#   'id': 29786300,
#   'lat': 52.5009998,
#   'lon': 13.3370889},
#  29786301: {'type': 'node',
#   'id': 29786301,
#   'lat': 52.4795953,
#   'lon': 13.3126628},
#  29786302: {'type': 'node',
#   'id': 29786302,
#   'lat': 52.4897089,
#   'lon': 13.3143797},
#  29786303: {'type': 'node',
#   'id': 29786303,
#   'lat': 52.5027248,
#   'lon': 13.3395659},
#  29786304: {'type': 'node',
#   'id': 29786304,
#   'lat': 52.4784923,
#   'lon': 13.3126114},
#  29786306: {'type': 'node',
#   'id': 29786306,
#   'lat': 52.4938073,
#   'lon': 13.3241785},
#  29786307: {'type': 'node',
#   'id': 29786307,
#   'lat': 52.46355,
#   'lon': 13.2943291},
#  29786308: {'type': 'node',
#   'id': 29786308,
#   'lat': 52.4649531,
#   'lon': 13.2982353},
#  29786310: {'type': 'node',
#   'id': 29786310,
#   'lat': 52.4584318,
#   'lon': 13.2906309},
#  29786312: {'type': 'node',
#   'id': 29786312,
#   'lat': 52.4697785,
#   'lon': 13.3124956},
#  29786315: {'type': 'node',
#   'id': 29786315,
#   'lat': 52.4889719,
#   'lon': 13.314098},
#  29786318: {'type': 'node',
#   'id': 29786318,
#   'lat': 52.5026812,
#   'lon': 13.3391815},
#  29786319: {'type': 'node',
#   'id': 29786319,
#   'lat': 52.472617,
#   'lon': 13.3144435},
#  29786320: {'type': 'node',
#   'id': 29786320,
#   'lat': 52.4945449,
#   'lon': 13.3261095},
#  29786321: {'type': 'node',
#   'id': 29786321,
#   'lat': 52.4658157,
#   'lon': 13.3061678},
#  29786322: {'type': 'node',
#   'id': 29786322,
#   'lat': 52.4617783,
#   'lon': 13.2921394},
#  29786324: {'type': 'node',
#   'id': 29786324,
#   'lat': 52.471696,
#   'lon': 13.3140439},
#  29786327: {'type': 'node',
#   'id': 29786327,
#   'lat': 52.5014121,
#   'lon': 13.3446601,
#   'tags': {'railway': 'switch'}},
#  29786328: {'type': 'node',
#   'id': 29786328,
#   'lat': 52.5024027,
#   'lon': 13.3385468},
#  29786330: {'type': 'node',
#   'id': 29786330,
#   'lat': 52.4887922,
#   'lon': 13.314069},
#  29786331: {'type': 'node',
#   'id': 29786331,
#   'lat': 52.4748788,
#   'lon': 13.3143609},
#  29786332: {'type': 'node',
#   'id': 29786332,
#   'lat': 52.4641373,
#   'lon': 13.2960006,
#   'tags': {'description': 'U Podbielskiallee, Gleis 2',
#    'name': 'Podbielskiallee',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '233902',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h233902'}},
#  29786334: {'type': 'node',
#   'id': 29786334,
#   'lat': 52.4625461,
#   'lon': 13.2927366},
#  29786335: {'type': 'node',
#   'id': 29786335,
#   'lat': 52.4669659,
#   'lon': 13.3088779,
#   'tags': {'description': 'U Breitenbachplatz, Gleis 2',
#    'name': 'Breitenbachplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '233802',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h233802'}},
#  29786337: {'type': 'node',
#   'id': 29786337,
#   'lat': 52.5000128,
#   'lon': 13.3510216},
#  29786338: {'type': 'node',
#   'id': 29786338,
#   'lat': 52.4984031,
#   'lon': 13.3344295},
#  29786341: {'type': 'node',
#   'id': 29786341,
#   'lat': 52.5024605,
#   'lon': 13.3386235},
#  29787624: {'type': 'node',
#   'id': 29787624,
#   'lat': 52.5028946,
#   'lon': 13.4472444},
#  29787626: {'type': 'node',
#   'id': 29787626,
#   'lat': 52.501159,
#   'lon': 13.4450644},
#  29787627: {'type': 'node',
#   'id': 29787627,
#   'lat': 52.5009661,
#   'lon': 13.4446758},
#  29787628: {'type': 'node',
#   'id': 29787628,
#   'lat': 52.5008975,
#   'lon': 13.4442796},
#  29787629: {'type': 'node',
#   'id': 29787629,
#   'lat': 52.5009174,
#   'lon': 13.4438519},
#  29787631: {'type': 'node',
#   'id': 29787631,
#   'lat': 52.5011057,
#   'lon': 13.4426465},
#  29787632: {'type': 'node',
#   'id': 29787632,
#   'lat': 52.5010717,
#   'lon': 13.4421733},
#  29787634: {'type': 'node',
#   'id': 29787634,
#   'lat': 52.5008434,
#   'lon': 13.4414409,
#   'tags': {'name': 'Schlesisches Tor',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '212201',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h212201'}},
#  29787635: {'type': 'node',
#   'id': 29787635,
#   'lat': 52.5006945,
#   'lon': 13.4407467,
#   'tags': {'railway': 'milestone', 'railway:position': '7.85'}},
#  29787636: {'type': 'node',
#   'id': 29787636,
#   'lat': 52.499418,
#   'lon': 13.4320277},
#  29787638: {'type': 'node',
#   'id': 29787638,
#   'lat': 52.4993819,
#   'lon': 13.4297734},
#  29787639: {'type': 'node',
#   'id': 29787639,
#   'lat': 52.4992519,
#   'lon': 13.4276166,
#   'tags': {'name': 'Görlitzer Bahnhof',
#    'name:ja': 'ゲルリッツァー駅',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '212301',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h212301'}},
#  29787640: {'type': 'node',
#   'id': 29787640,
#   'lat': 52.4991367,
#   'lon': 13.4221138},
#  29808632: {'type': 'node',
#   'id': 29808632,
#   'lat': 52.5034696,
#   'lon': 13.5157039},
#  29808633: {'type': 'node',
#   'id': 29808633,
#   'lat': 52.5021875,
#   'lon': 13.5177687},
#  29808634: {'type': 'node',
#   'id': 29808634,
#   'lat': 52.501218,
#   'lon': 13.5198262},
#  29808635: {'type': 'node',
#   'id': 29808635,
#   'lat': 52.5075269,
#   'lon': 13.5103624},
#  29808640: {'type': 'node',
#   'id': 29808640,
#   'lat': 52.5123051,
#   'lon': 13.4882185},
#  29833425: {'type': 'node',
#   'id': 29833425,
#   'lat': 52.4941849,
#   'lon': 13.3092859,
#   'tags': {'description': 'U Konstanzer Straße, Gleis',
#    'level': '-2',
#    'name': 'Konstanzer Straße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '273601',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h273601',
#    'wikidata': 'Q571019',
#    'wikipedia': 'de:U-Bahnhof Konstanzer Straße'}},
#  29833444: {'type': 'node',
#   'id': 29833444,
#   'lat': 52.4888043,
#   'lon': 13.3163924},
#  29833449: {'type': 'node',
#   'id': 29833449,
#   'lat': 52.4869734,
#   'lon': 13.3195131},
#  29833455: {'type': 'node',
#   'id': 29833455,
#   'lat': 52.4867782,
#   'lon': 13.3198561},
#  29833460: {'type': 'node',
#   'id': 29833460,
#   'lat': 52.4864532,
#   'lon': 13.3207807},
#  29833477: {'type': 'node',
#   'id': 29833477,
#   'lat': 52.4955068,
#   'lon': 13.3084249},
#  29833484: {'type': 'node',
#   'id': 29833484,
#   'lat': 52.5004767,
#   'lon': 13.307401},
#  29833491: {'type': 'node',
#   'id': 29833491,
#   'lat': 52.5002423,
#   'lon': 13.307399,
#   'tags': {'description': 'U Adenauerplatz, Gleis',
#    'level': '-2',
#    'name': 'Adenauerplatz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '273502',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h273502'}},
#  29833498: {'type': 'node',
#   'id': 29833498,
#   'lat': 52.5029213,
#   'lon': 13.3077783},
#  29880177: {'type': 'node',
#   'id': 29880177,
#   'lat': 52.4960364,
#   'lon': 13.5240042},
#  29880181: {'type': 'node',
#   'id': 29880181,
#   'lat': 52.4948771,
#   'lon': 13.5266443},
#  29880183: {'type': 'node',
#   'id': 29880183,
#   'lat': 52.4951777,
#   'lon': 13.5284102},
#  29880185: {'type': 'node',
#   'id': 29880185,
#   'lat': 52.4996732,
#   'lon': 13.5463978,
#   'tags': {'name': 'Biesdorf-Süd',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252901',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252901'}},
#  29880187: {'type': 'node',
#   'id': 29880187,
#   'lat': 52.5015169,
#   'lon': 13.5533021},
#  29880189: {'type': 'node',
#   'id': 29880189,
#   'lat': 52.5018945,
#   'lon': 13.5544377},
#  29880191: {'type': 'node',
#   'id': 29880191,
#   'lat': 52.5028424,
#   'lon': 13.5567618},
#  29881305: {'type': 'node',
#   'id': 29881305,
#   'lat': 52.5031704,
#   'lon': 13.5574636},
#  29881306: {'type': 'node',
#   'id': 29881306,
#   'lat': 52.5034312,
#   'lon': 13.5579709},
#  29881307: {'type': 'node',
#   'id': 29881307,
#   'lat': 52.5036766,
#   'lon': 13.5584102},
#  29881312: {'type': 'node',
#   'id': 29881312,
#   'lat': 52.5083195,
#   'lon': 13.564946},
#  29881351: {'type': 'node',
#   'id': 29881351,
#   'lat': 52.5101044,
#   'lon': 13.567386},
#  29881352: {'type': 'node',
#   'id': 29881352,
#   'lat': 52.5106242,
#   'lon': 13.5682206},
#  29881353: {'type': 'node',
#   'id': 29881353,
#   'lat': 52.5112372,
#   'lon': 13.5692355},
#  29881354: {'type': 'node',
#   'id': 29881354,
#   'lat': 52.5117695,
#   'lon': 13.5701359},
#  29881355: {'type': 'node',
#   'id': 29881355,
#   'lat': 52.5122942,
#   'lon': 13.571308},
#  29881356: {'type': 'node',
#   'id': 29881356,
#   'lat': 52.5124588,
#   'lon': 13.5719294},
#  29881357: {'type': 'node',
#   'id': 29881357,
#   'lat': 52.5126139,
#   'lon': 13.5733619},
#  30019727: {'type': 'node',
#   'id': 30019727,
#   'lat': 52.5367825,
#   'lon': 13.3972532},
#  30305204: {'type': 'node',
#   'id': 30305204,
#   'lat': 52.5569004,
#   'lon': 13.4143511},
#  31011889: {'type': 'node',
#   'id': 31011889,
#   'lat': 52.4987457,
#   'lon': 13.5426307},
#  31034993: {'type': 'node',
#   'id': 31034993,
#   'lat': 52.4605701,
#   'lon': 13.3848532},
#  31034996: {'type': 'node',
#   'id': 31034996,
#   'lat': 52.456982,
#   'lon': 13.3840106},
#  31034997: {'type': 'node',
#   'id': 31034997,
#   'lat': 52.4548875,
#   'lon': 13.3843291},
#  31034998: {'type': 'node',
#   'id': 31034998,
#   'lat': 52.4542319,
#   'lon': 13.3844566,
#   'tags': {'name': 'Ullsteinstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '264702',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h264702'}},
#  31034999: {'type': 'node',
#   'id': 31034999,
#   'lat': 52.446277,
#   'lon': 13.3857568,
#   'tags': {'description': 'U Westphalweg, Gleis 2',
#    'name': 'Westphalweg',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '264802',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h264802'}},
#  31207786: {'type': 'node',
#   'id': 31207786,
#   'lat': 52.5065311,
#   'lon': 13.3066037,
#   'tags': {'level': '-2',
#    'name': 'Wilmersdorfer Straße',
#    'name:ja': 'ヴィルマースドルファー通り',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '273401',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h273401'}},
#  31207788: {'type': 'node',
#   'id': 31207788,
#   'lat': 52.5032077,
#   'lon': 13.3077093},
#  31207791: {'type': 'node',
#   'id': 31207791,
#   'lat': 52.5152499,
#   'lon': 13.3063355},
#  31207793: {'type': 'node',
#   'id': 31207793,
#   'lat': 52.5185468,
#   'lon': 13.3062962},
#  31207794: {'type': 'node',
#   'id': 31207794,
#   'lat': 52.5209335,
#   'lon': 13.3065141},
#  31729333: {'type': 'node',
#   'id': 31729333,
#   'lat': 52.4984002,
#   'lon': 13.4050918,
#   'tags': {'name': 'Prinzenstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '212501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h212501'}},
#  38901926: {'type': 'node',
#   'id': 38901926,
#   'lat': 52.5233166,
#   'lon': 13.3059405},
#  38901927: {'type': 'node',
#   'id': 38901927,
#   'lat': 52.5243945,
#   'lon': 13.3059993},
#  38901928: {'type': 'node',
#   'id': 38901928,
#   'lat': 52.5253247,
#   'lon': 13.3056641},
#  38901931: {'type': 'node',
#   'id': 38901931,
#   'lat': 52.5298881,
#   'lon': 13.3009418},
#  38901932: {'type': 'node',
#   'id': 38901932,
#   'lat': 52.5312844,
#   'lon': 13.3005527},
#  38901933: {'type': 'node',
#   'id': 38901933,
#   'lat': 52.5319045,
#   'lon': 13.3005314},
#  38901937: {'type': 'node',
#   'id': 38901937,
#   'lat': 52.5359248,
#   'lon': 13.2964415},
#  38901938: {'type': 'node',
#   'id': 38901938,
#   'lat': 52.5356817,
#   'lon': 13.2975154},
#  38901941: {'type': 'node',
#   'id': 38901941,
#   'lat': 52.5365534,
#   'lon': 13.2902556},
#  38901942: {'type': 'node',
#   'id': 38901942,
#   'lat': 52.5365733,
#   'lon': 13.2864407,
#   'tags': {'alt_name': 'U-Bhf Halemweg',
#    'name': 'Halemweg',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272801',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h272801'}},
#  38901943: {'type': 'node',
#   'id': 38901943,
#   'lat': 52.5368624,
#   'lon': 13.2778654},
#  38901944: {'type': 'node',
#   'id': 38901944,
#   'lat': 52.5367004,
#   'lon': 13.2727725,
#   'tags': {'alt_name': 'U-Bhf Siemensdamm',
#    'name': 'Siemensdamm',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272701',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h272701'}},
#  38901946: {'type': 'node',
#   'id': 38901946,
#   'lat': 52.5263256,
#   'lon': 13.3046696,
#   'tags': {'name': 'Mierendorffplatz',
#    'name:ja': 'ミアーエンドルフプラッツ',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '273101',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h273101'}},
#  38902377: {'type': 'node',
#   'id': 38902377,
#   'lat': 52.5369093,
#   'lon': 13.2626037,
#   'tags': {'name': 'Rohrdamm',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272601',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h272601'}},
#  38902430: {'type': 'node',
#   'id': 38902430,
#   'lat': 52.5379106,
#   'lon': 13.2478023,
#   'tags': {'level': '-2',
#    'name': 'Paulsternstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h272501'}},
#  38902431: {'type': 'node',
#   'id': 38902431,
#   'lat': 52.5389555,
#   'lon': 13.2375804},
#  38902432: {'type': 'node',
#   'id': 38902432,
#   'lat': 52.5388566,
#   'lon': 13.234575},
#  38902433: {'type': 'node',
#   'id': 38902433,
#   'lat': 52.5386082,
#   'lon': 13.2329554,
#   'tags': {'name': 'Haselhorst',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272401',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h272401'}},
#  38902434: {'type': 'node',
#   'id': 38902434,
#   'lat': 52.5378079,
#   'lon': 13.228053},
#  38902435: {'type': 'node',
#   'id': 38902435,
#   'lat': 52.5369029,
#   'lon': 13.2213852},
#  38902437: {'type': 'node',
#   'id': 38902437,
#   'lat': 52.5378821,
#   'lon': 13.2167292},
#  38902438: {'type': 'node',
#   'id': 38902438,
#   'lat': 52.5383892,
#   'lon': 13.2130409},
#  38902439: {'type': 'node',
#   'id': 38902439,
#   'lat': 52.5382637,
#   'lon': 13.2122411},
#  38902440: {'type': 'node',
#   'id': 38902440,
#   'lat': 52.5381268,
#   'lon': 13.2111777},
#  38902441: {'type': 'node',
#   'id': 38902441,
#   'lat': 52.5380841,
#   'lon': 13.209947},
#  38902442: {'type': 'node',
#   'id': 38902442,
#   'lat': 52.538212,
#   'lon': 13.2085482},
#  38902443: {'type': 'node',
#   'id': 38902443,
#   'lat': 52.5389737,
#   'lon': 13.2055259,
#   'tags': {'name': 'Altstadt Spandau',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272201',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h272201'}},
#  38902444: {'type': 'node',
#   'id': 38902444,
#   'lat': 52.5391349,
#   'lon': 13.2044138},
#  38902445: {'type': 'node',
#   'id': 38902445,
#   'lat': 52.5390651,
#   'lon': 13.2031142},
#  38902446: {'type': 'node',
#   'id': 38902446,
#   'lat': 52.5386277,
#   'lon': 13.2016875},
#  38902447: {'type': 'node',
#   'id': 38902447,
#   'lat': 52.5382122,
#   'lon': 13.2010266},
#  38902448: {'type': 'node',
#   'id': 38902448,
#   'lat': 52.5377283,
#   'lon': 13.2005625},
#  38902450: {'type': 'node',
#   'id': 38902450,
#   'lat': 52.5361184,
#   'lon': 13.2001504},
#  38902451: {'type': 'node',
#   'id': 38902451,
#   'lat': 52.5354269,
#   'lon': 13.1999509,
#   'tags': {'name': 'Rathaus Spandau',
#    'name:BVG': 'S+U Rathaus Spandau',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '272101',
#    'subway': 'yes',
#    'surveillance': 'indoor',
#    'website': 'https://qr.bvg.de/h272101'}},
#  52149772: {'type': 'node',
#   'id': 52149772,
#   'lat': 52.5163537,
#   'lon': 13.4180404},
#  52684988: {'type': 'node',
#   'id': 52684988,
#   'lat': 52.5382584,
#   'lon': 13.6336218,
#   'tags': {'name': 'Hönow',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252102'}},
#  52684989: {'type': 'node',
#   'id': 52684989,
#   'lat': 52.5389706,
#   'lon': 13.6302529,
#   'tags': {'railway': 'switch',
#    'railway:turnout_side': 'left',
#    'source': 'Bing'}},
#  52684991: {'type': 'node',
#   'id': 52684991,
#   'lat': 52.539333,
#   'lon': 13.6267295},
#  52684992: {'type': 'node',
#   'id': 52684992,
#   'lat': 52.5393737,
#   'lon': 13.6230044},
#  52684997: {'type': 'node',
#   'id': 52684997,
#   'lat': 52.5391468,
#   'lon': 13.6202237,
#   'tags': {'railway': 'switch',
#    'railway:turnout_side': 'right',
#    'source': 'Bing'}},
#  52692776: {'type': 'node',
#   'id': 52692776,
#   'lat': 52.5384399,
#   'lon': 13.6149074},
#  52692780: {'type': 'node',
#   'id': 52692780,
#   'lat': 52.5372613,
#   'lon': 13.6092654},
#  52692783: {'type': 'node',
#   'id': 52692783,
#   'lat': 52.5339777,
#   'lon': 13.5971793,
#   'tags': {'name': 'Cottbusser Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252402',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252402'}},
#  53274719: {'type': 'node',
#   'id': 53274719,
#   'lat': 52.5128301,
#   'lon': 13.5790452},
#  53274720: {'type': 'node',
#   'id': 53274720,
#   'lat': 52.5141131,
#   'lon': 13.5818562},
#  53274721: {'type': 'node',
#   'id': 53274721,
#   'lat': 52.5193355,
#   'lon': 13.5890815},
#  53274722: {'type': 'node',
#   'id': 53274722,
#   'lat': 52.5211222,
#   'lon': 13.5890346,
#   'tags': {'name': 'Kaulsdorf-Nord',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252602',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252602'}},
#  53274723: {'type': 'node',
#   'id': 53274723,
#   'lat': 52.5235439,
#   'lon': 13.5888595},
#  53274724: {'type': 'node',
#   'id': 53274724,
#   'lat': 52.5255912,
#   'lon': 13.5892615},
#  53274725: {'type': 'node',
#   'id': 53274725,
#   'lat': 52.5285704,
#   'lon': 13.5906901,
#   'tags': {'name': 'Kienberg (Gärten der Welt)',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252502',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252502'}},
#  53274727: {'type': 'node',
#   'id': 53274727,
#   'lat': 52.5321235,
#   'lon': 13.5927004},
#  53274728: {'type': 'node',
#   'id': 53274728,
#   'lat': 52.5327198,
#   'lon': 13.5935177},
#  53274729: {'type': 'node',
#   'id': 53274729,
#   'lat': 52.5332284,
#   'lon': 13.5946078},
#  53274733: {'type': 'node',
#   'id': 53274733,
#   'lat': 52.5172415,
#   'lon': 13.5879279},
#  53274734: {'type': 'node',
#   'id': 53274734,
#   'lat': 52.5130115,
#   'lon': 13.5795705},
#  53274779: {'type': 'node',
#   'id': 53274779,
#   'lat': 52.4949737,
#   'lon': 13.5258672},
#  53274780: {'type': 'node',
#   'id': 53274780,
#   'lat': 52.4955712,
#   'lon': 13.5245017},
#  53593108: {'type': 'node',
#   'id': 53593108,
#   'lat': 52.4557692,
#   'lon': 13.3840629},
#  55188138: {'type': 'node',
#   'id': 55188138,
#   'lat': 52.5179915,
#   'lon': 13.5885939},
#  55189254: {'type': 'node',
#   'id': 55189254,
#   'lat': 52.5148582,
#   'lon': 13.4638612,
#   'tags': {'name': 'Samariterstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '253501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h253501'}},
#  55189257: {'type': 'node',
#   'id': 55189257,
#   'lat': 52.5184451,
#   'lon': 13.4290465},
#  55189763: {'type': 'node',
#   'id': 55189763,
#   'lat': 52.5191138,
#   'lon': 13.4264555},
#  55189765: {'type': 'node',
#   'id': 55189765,
#   'lat': 52.5206939,
#   'lon': 13.4212287,
#   'tags': {'description': 'U Schillingstraße, Gleis 2',
#    'name': 'Schillingstraße',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '253902',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h253902'}},
#  55189767: {'type': 'node',
#   'id': 55189767,
#   'lat': 52.5221682,
#   'lon': 13.4152971},
#  55189770: {'type': 'node',
#   'id': 55189770,
#   'lat': 52.5220589,
#   'lon': 13.4149498},
#  55189871: {'type': 'node',
#   'id': 55189871,
#   'lat': 52.5222358,
#   'lon': 13.4158755},
#  59893238: {'type': 'node',
#   'id': 59893238,
#   'lat': 52.5534758,
#   'lon': 13.3704703},
#  60177051: {'type': 'node',
#   'id': 60177051,
#   'lat': 52.5623093,
#   'lon': 13.3305499},
#  60381269: {'type': 'node',
#   'id': 60381269,
#   'lat': 52.4811417,
#   'lon': 13.3291603},
#  60381272: {'type': 'node',
#   'id': 60381272,
#   'lat': 52.4838421,
#   'lon': 13.3309913},
#  60381276: {'type': 'node',
#   'id': 60381276,
#   'lat': 52.4840671,
#   'lon': 13.3310674},
#  60381279: {'type': 'node',
#   'id': 60381279,
#   'lat': 52.4808344,
#   'lon': 13.3289608},
#  60662272: {'type': 'node',
#   'id': 60662272,
#   'lat': 52.5208943,
#   'lon': 13.4147987},
#  60662274: {'type': 'node',
#   'id': 60662274,
#   'lat': 52.5213058,
#   'lon': 13.4146525},
#  76474607: {'type': 'node',
#   'id': 76474607,
#   'lat': 52.490342,
#   'lon': 13.3578142},
#  76551221: {'type': 'node',
#   'id': 76551221,
#   'lat': 52.4638569,
#   'lon': 13.2952244},
#  86001866: {'type': 'node',
#   'id': 86001866,
#   'lat': 52.5112213,
#   'lon': 13.4052044,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'left'}},
#  86001869: {'type': 'node',
#   'id': 86001869,
#   'lat': 52.5112156,
#   'lon': 13.4055646},
#  86005427: {'type': 'node',
#   'id': 86005427,
#   'lat': 52.5132014,
#   'lon': 13.3938333},
#  91711764: {'type': 'node',
#   'id': 91711764,
#   'lat': 52.5598158,
#   'lon': 13.4132867},
#  91711767: {'type': 'node',
#   'id': 91711767,
#   'lat': 52.5585745,
#   'lon': 13.4134625},
#  91711770: {'type': 'node',
#   'id': 91711770,
#   'lat': 52.561154,
#   'lon': 13.4131712},
#  91711771: {'type': 'node',
#   'id': 91711771,
#   'lat': 52.5626503,
#   'lon': 13.4129618},
#  91711775: {'type': 'node',
#   'id': 91711775,
#   'lat': 52.565273,
#   'lon': 13.4125794},
#  91711785: {'type': 'node',
#   'id': 91711785,
#   'lat': 52.5540172,
#   'lon': 13.4146003},
#  91711790: {'type': 'node',
#   'id': 91711790,
#   'lat': 52.5521488,
#   'lon': 13.4142111},
#  91711798: {'type': 'node',
#   'id': 91711798,
#   'lat': 52.5505955,
#   'lon': 13.4139357},
#  91711807: {'type': 'node',
#   'id': 91711807,
#   'lat': 52.5496958,
#   'lon': 13.413824,
#   'tags': {'name': 'Schönhauser Allee',
#    'name:BVG': 'S+U Schönhauser Allee',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '222202',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h222202'}},
#  91711815: {'type': 'node',
#   'id': 91711815,
#   'lat': 52.5438887,
#   'lon': 13.4124148},
#  91711825: {'type': 'node', 'id': 91711825, 'lat': 52.5453, 'lon': 13.4127923},
#  91711827: {'type': 'node',
#   'id': 91711827,
#   'lat': 52.5424588,
#   'lon': 13.412314},
#  91720344: {'type': 'node',
#   'id': 91720344,
#   'lat': 52.5380959,
#   'lon': 13.4122459},
#  92605918: {'type': 'node',
#   'id': 92605918,
#   'lat': 52.5367914,
#   'lon': 13.4123624},
#  95041107: {'type': 'node',
#   'id': 95041107,
#   'lat': 52.5382272,
#   'lon': 13.2440122},
#  95041110: {'type': 'node',
#   'id': 95041110,
#   'lat': 52.5382404,
#   'lon': 13.2306394},
#  95041117: {'type': 'node',
#   'id': 95041117,
#   'lat': 52.5369416,
#   'lon': 13.2204494},
#  95041121: {'type': 'node',
#   'id': 95041121,
#   'lat': 52.5384082,
#   'lon': 13.2139874},
#  95717546: {'type': 'node',
#   'id': 95717546,
#   'lat': 52.5038766,
#   'lon': 13.4480414,
#   'tags': {'railway': 'switch', 'source': 'Bing'}},
#  95924989: {'type': 'node',
#   'id': 95924989,
#   'lat': 52.5393655,
#   'lon': 13.6241071,
#   'tags': {'railway': 'railway_crossing', 'source': 'Bing'}},
#  95925219: {'type': 'node',
#   'id': 95925219,
#   'lat': 52.5393401,
#   'lon': 13.6219075},
#  104515033: {'type': 'node',
#   'id': 104515033,
#   'lat': 52.5085015,
#   'lon': 13.377442,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  107020135: {'type': 'node',
#   'id': 107020135,
#   'lat': 52.5158709,
#   'lon': 13.4540123,
#   'tags': {'description': 'U Frankfurter Tor, Gleis 1',
#    'name': 'Frankfurter Tor',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '253601',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h253601'}},
#  111651320: {'type': 'node',
#   'id': 111651320,
#   'lat': 52.4903903,
#   'lon': 13.3586672},
#  111651323: {'type': 'node',
#   'id': 111651323,
#   'lat': 52.4902802,
#   'lon': 13.3605865},
#  111651331: {'type': 'node',
#   'id': 111651331,
#   'lat': 52.491912,
#   'lon': 13.3674356},
#  114097627: {'type': 'node',
#   'id': 114097627,
#   'lat': 52.509954,
#   'lon': 13.3794217},
#  114099456: {'type': 'node',
#   'id': 114099456,
#   'lat': 52.508635,
#   'lon': 13.3775648},
#  114101018: {'type': 'node',
#   'id': 114101018,
#   'lat': 52.5068604,
#   'lon': 13.3764782},
#  114101251: {'type': 'node',
#   'id': 114101251,
#   'lat': 52.5110372,
#   'lon': 13.3809565},
#  114103482: {'type': 'node',
#   'id': 114103482,
#   'lat': 52.5190797,
#   'lon': 13.4115013},
#  114104901: {'type': 'node',
#   'id': 114104901,
#   'lat': 52.5242603,
#   'lon': 13.409975},
#  114113799: {'type': 'node',
#   'id': 114113799,
#   'lat': 52.4986514,
#   'lon': 13.3740042,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  116095833: {'type': 'node',
#   'id': 116095833,
#   'lat': 52.489589,
#   'lon': 13.3143109},
#  116798403: {'type': 'node',
#   'id': 116798403,
#   'lat': 52.4989896,
#   'lon': 13.381897},
#  116798405: {'type': 'node',
#   'id': 116798405,
#   'lat': 52.4990944,
#   'lon': 13.3818693},
#  116798409: {'type': 'node',
#   'id': 116798409,
#   'lat': 52.4991494,
#   'lon': 13.3823489},
#  116798412: {'type': 'node',
#   'id': 116798412,
#   'lat': 52.4991783,
#   'lon': 13.3827225},
#  116798417: {'type': 'node',
#   'id': 116798417,
#   'lat': 52.4991872,
#   'lon': 13.3830605},
#  116798419: {'type': 'node',
#   'id': 116798419,
#   'lat': 52.4991795,
#   'lon': 13.3833285},
#  116798422: {'type': 'node',
#   'id': 116798422,
#   'lat': 52.4991532,
#   'lon': 13.383558},
#  116798425: {'type': 'node',
#   'id': 116798425,
#   'lat': 52.4990558,
#   'lon': 13.3835433},
#  116798430: {'type': 'node',
#   'id': 116798430,
#   'lat': 52.4990505,
#   'lon': 13.3830702},
#  116798434: {'type': 'node',
#   'id': 116798434,
#   'lat': 52.4990494,
#   'lon': 13.382946},
#  116798437: {'type': 'node',
#   'id': 116798437,
#   'lat': 52.499029,
#   'lon': 13.3825698},
#  116798439: {'type': 'node',
#   'id': 116798439,
#   'lat': 52.4990044,
#   'lon': 13.3822456},
#  117981609: {'type': 'node',
#   'id': 117981609,
#   'lat': 52.4834813,
#   'lon': 13.3136561},
# ...
#    'railway:signal:direction': 'forward',
#    'railway:signal:position': 'right',
#    'ref': 'Gro A1'}},
#  482734768: {'type': 'node',
#   'id': 482734768,
#   'lat': 52.4982275,
#   'lon': 13.3953124},
#  497760562: {'type': 'node',
#   'id': 497760562,
#   'lat': 52.4948887,
#   'lon': 13.5272341},
#  499559675: {'type': 'node',
#   'id': 499559675,
#   'lat': 52.4997968,
#   'lon': 13.3741172},
#  499559678: {'type': 'node',
#   'id': 499559678,
#   'lat': 52.5004446,
#   'lon': 13.3740476},
#  499559680: {'type': 'node',
#   'id': 499559680,
#   'lat': 52.5007725,
#   'lon': 13.3740286},
#  499559681: {'type': 'node',
#   'id': 499559681,
#   'lat': 52.500777,
#   'lon': 13.3740976},
#  499559683: {'type': 'node',
#   'id': 499559683,
#   'lat': 52.499266,
#   'lon': 13.3742217},
#  499559685: {'type': 'node',
#   'id': 499559685,
#   'lat': 52.4996312,
#   'lon': 13.3743136},
#  499559687: {'type': 'node',
#   'id': 499559687,
#   'lat': 52.4994574,
#   'lon': 13.3754006},
#  499559690: {'type': 'node',
#   'id': 499559690,
#   'lat': 52.4995323,
#   'lon': 13.3754338},
#  499559692: {'type': 'node',
#   'id': 499559692,
#   'lat': 52.4995024,
#   'lon': 13.3732852,
#   'tags': {'railway': 'switch',
#    'railway:turnout_side': 'right',
#    'source': 'Bing'}},
#  499559694: {'type': 'node',
#   'id': 499559694,
#   'lat': 52.4993391,
#   'lon': 13.3768887},
#  499559696: {'type': 'node',
#   'id': 499559696,
#   'lat': 52.4993628,
#   'lon': 13.3770971},
#  515666572: {'type': 'node',
#   'id': 515666572,
#   'lat': 52.500843,
#   'lon': 13.4412369},
#  519262801: {'type': 'node',
#   'id': 519262801,
#   'lat': 52.5303979,
#   'lon': 13.4109885},
#  522099138: {'type': 'node',
#   'id': 522099138,
#   'lat': 52.4978278,
#   'lon': 13.539107},
#  524647694: {'type': 'node',
#   'id': 524647694,
#   'lat': 52.4994636,
#   'lon': 13.3740857},
#  524657889: {'type': 'node',
#   'id': 524657889,
#   'lat': 52.5121513,
#   'lon': 13.3912194,
#   'tags': {'name': 'Stadtmitte',
#    'name:BVG': 'U Stadtmitte U2',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '223102',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h223102'}},
#  524760550: {'type': 'node',
#   'id': 524760550,
#   'lat': 52.4526939,
#   'lon': 13.3846528},
#  524760564: {'type': 'node',
#   'id': 524760564,
#   'lat': 52.4543927,
#   'lon': 13.3844271},
#  524760583: {'type': 'node',
#   'id': 524760583,
#   'lat': 52.4565156,
#   'lon': 13.3839892},
#  530797130: {'type': 'node',
#   'id': 530797130,
#   'lat': 52.4881295,
#   'lon': 13.3361244},
#  553049870: {'type': 'node',
#   'id': 553049870,
#   'lat': 52.5042376,
#   'lon': 13.4483462},
#  553049899: {'type': 'node',
#   'id': 553049899,
#   'lat': 52.5051139,
#   'lon': 13.4490193},
#  557826997: {'type': 'node',
#   'id': 557826997,
#   'lat': 52.5075492,
#   'lon': 13.5638987},
#  557827044: {'type': 'node',
#   'id': 557827044,
#   'lat': 52.5061514,
#   'lon': 13.5621135},
#  557827057: {'type': 'node',
#   'id': 557827057,
#   'lat': 52.5054484,
#   'lon': 13.5611929,
#   'tags': {'description': 'U Elsterwerdaer Platz, Gleis 2',
#    'name': 'Elsterwerdaer Platz',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252802',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252802'}},
#  557827093: {'type': 'node',
#   'id': 557827093,
#   'lat': 52.5038895,
#   'lon': 13.5589552},
#  557827108: {'type': 'node',
#   'id': 557827108,
#   'lat': 52.5036389,
#   'lon': 13.5584929},
#  557827123: {'type': 'node',
#   'id': 557827123,
#   'lat': 52.5031464,
#   'lon': 13.557515},
#  557827136: {'type': 'node',
#   'id': 557827136,
#   'lat': 52.5024979,
#   'lon': 13.5560825},
#  557827484: {'type': 'node',
#   'id': 557827484,
#   'lat': 52.5056914,
#   'lon': 13.5615231},
#  557829002: {'type': 'node',
#   'id': 557829002,
#   'lat': 52.5022447,
#   'lon': 13.5553562},
#  557829014: {'type': 'node',
#   'id': 557829014,
#   'lat': 52.5025294,
#   'lon': 13.5560484},
#  557838461: {'type': 'node',
#   'id': 557838461,
#   'lat': 52.5008937,
#   'lon': 13.5514609},
#  557838472: {'type': 'node',
#   'id': 557838472,
#   'lat': 52.500477,
#   'lon': 13.5499302},
#  557838523: {'type': 'node',
#   'id': 557838523,
#   'lat': 52.5003087,
#   'lon': 13.549357,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  557838540: {'type': 'node',
#   'id': 557838540,
#   'lat': 52.4999504,
#   'lon': 13.54819},
#  557838553: {'type': 'node',
#   'id': 557838553,
#   'lat': 52.4998418,
#   'lon': 13.5478183},
#  557838583: {'type': 'node',
#   'id': 557838583,
#   'lat': 52.4993206,
#   'lon': 13.545711},
#  557838591: {'type': 'node',
#   'id': 557838591,
#   'lat': 52.4992423,
#   'lon': 13.5453563},
#  557838605: {'type': 'node',
#   'id': 557838605,
#   'lat': 52.4992118,
#   'lon': 13.5451992},
#  557838636: {'type': 'node',
#   'id': 557838636,
#   'lat': 52.498897,
#   'lon': 13.5434593,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  557838648: {'type': 'node',
#   'id': 557838648,
#   'lat': 52.4988246,
#   'lon': 13.5431138},
#  557839618: {'type': 'node',
#   'id': 557839618,
#   'lat': 52.5000542,
#   'lon': 13.5479135,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  557840307: {'type': 'node',
#   'id': 557840307,
#   'lat': 52.4990027,
#   'lon': 13.543667,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  557840370: {'type': 'node',
#   'id': 557840370,
#   'lat': 52.5006912,
#   'lon': 13.5502709,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'left'}},
#  557841454: {'type': 'node',
#   'id': 557841454,
#   'lat': 52.4995098,
#   'lon': 13.5464812,
#   'tags': {'name': 'Biesdorf-Süd',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252902',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252902'}},
#  557841941: {'type': 'node',
#   'id': 557841941,
#   'lat': 52.4997521,
#   'lon': 13.5474053},
#  557841955: {'type': 'node',
#   'id': 557841955,
#   'lat': 52.4993648,
#   'lon': 13.5458462},
#  557842257: {'type': 'node',
#   'id': 557842257,
#   'lat': 52.4995298,
#   'lon': 13.5457593},
#  557842267: {'type': 'node',
#   'id': 557842267,
#   'lat': 52.5000536,
#   'lon': 13.5478681},
#  558558226: {'type': 'node',
#   'id': 558558226,
#   'lat': 52.5022166,
#   'lon': 13.5553975},
#  558558229: {'type': 'node',
#   'id': 558558229,
#   'lat': 52.5018566,
#   'lon': 13.5544679},
#  558558231: {'type': 'node',
#   'id': 558558231,
#   'lat': 52.501653,
#   'lon': 13.5538893},
#  558558238: {'type': 'node',
#   'id': 558558238,
#   'lat': 52.5014337,
#   'lon': 13.5532458},
#  558558239: {'type': 'node',
#   'id': 558558239,
#   'lat': 52.5012216,
#   'lon': 13.5525845},
#  559506248: {'type': 'node',
#   'id': 559506248,
#   'lat': 52.5327466,
#   'lon': 13.5934717},
#  559506249: {'type': 'node',
#   'id': 559506249,
#   'lat': 52.5332823,
#   'lon': 13.5945169},
#  559506250: {'type': 'node',
#   'id': 559506250,
#   'lat': 52.5336845,
#   'lon': 13.5955883},
#  559506251: {'type': 'node',
#   'id': 559506251,
#   'lat': 52.5353838,
#   'lon': 13.601855},
#  559506253: {'type': 'node',
#   'id': 559506253,
#   'lat': 52.5361664,
#   'lon': 13.6043957},
#  559506254: {'type': 'node',
#   'id': 559506254,
#   'lat': 52.5370875,
#   'lon': 13.6079226},
#  559506255: {'type': 'node',
#   'id': 559506255,
#   'lat': 52.5375876,
#   'lon': 13.6105311},
#  559506256: {'type': 'node',
#   'id': 559506256,
#   'lat': 52.5388531,
#   'lon': 13.6168669},
#  559506257: {'type': 'node',
#   'id': 559506257,
#   'lat': 52.5387497,
#   'lon': 13.616213},
#  559506258: {'type': 'node',
#   'id': 559506258,
#   'lat': 52.5392772,
#   'lon': 13.6202099,
#   'tags': {'railway': 'switch',
#    'railway:turnout_side': 'right',
#    'source': 'Bing'}},
#  560099803: {'type': 'node',
#   'id': 560099803,
#   'lat': 52.5028129,
#   'lon': 13.5568024},
#  560099805: {'type': 'node',
#   'id': 560099805,
#   'lat': 52.5075687,
#   'lon': 13.5638484},
#  560099806: {'type': 'node',
#   'id': 560099806,
#   'lat': 52.5083359,
#   'lon': 13.5649145},
#  560099807: {'type': 'node',
#   'id': 560099807,
#   'lat': 52.507966,
#   'lon': 13.5643996},
#  560099808: {'type': 'node',
#   'id': 560099808,
#   'lat': 52.5104089,
#   'lon': 13.5677748},
#  560099809: {'type': 'node',
#   'id': 560099809,
#   'lat': 52.5103701,
#   'lon': 13.5677889,
#   'tags': {'operator': 'Berliner Verkehrsbetriebe',
#    'railway': 'signal',
#    'railway:signal:direction': 'forward',
#    'railway:signal:distant': 'DE-BVG:v',
#    'railway:signal:distant:deactivated': 'no',
#    'railway:signal:distant:form': 'light',
#    'railway:signal:distant:height': 'normal',
#    'railway:signal:distant:states': 'DE-BVG:v0;DE-BVG:v1',
#    'railway:signal:position': 'right',
#    'ref': 'Wh VE2 VN2'}},
#  560099810: {'type': 'node',
#   'id': 560099810,
#   'lat': 52.5101249,
#   'lon': 13.5673452},
#  560099816: {'type': 'node',
#   'id': 560099816,
#   'lat': 52.5108898,
#   'lon': 13.5686554,
#   'tags': {'operator': 'Berliner Verkehrsbetriebe',
#    'railway': 'switch',
#    'railway:switch': 'default',
#    'railway:switch:electric': 'yes',
#    'railway:switch:movable_frog': 'no',
#    'railway:switch:resetting': 'no',
#    'railway:turnout_side': 'right',
#    'ref': '272'}},
#  560099821: {'type': 'node',
#   'id': 560099821,
#   'lat': 52.5111068,
#   'lon': 13.5690298,
#   'tags': {'operator': 'Berliner Verkehrsbetriebe',
#    'railway': 'switch',
#    'railway:switch': 'default',
#    'railway:switch:electric': 'yes',
#    'railway:switch:movable_frog': 'no',
#    'railway:switch:resetting': 'no',
#    'railway:turnout_side': 'right',
#    'ref': '274'}},
#  560099828: {'type': 'node',
#   'id': 560099828,
#   'lat': 52.5115428,
#   'lon': 13.5696708},
#  560099829: {'type': 'node',
#   'id': 560099829,
#   'lat': 52.5119052,
#   'lon': 13.5703839},
#  560099838: {'type': 'node',
#   'id': 560099838,
#   'lat': 52.5119336,
#   'lon': 13.5703457},
#  560112939: {'type': 'node',
#   'id': 560112939,
#   'lat': 52.5132432,
#   'lon': 13.5800995},
#  560112954: {'type': 'node',
#   'id': 560112954,
#   'lat': 52.5134928,
#   'lon': 13.5805982},
#  560115542: {'type': 'node',
#   'id': 560115542,
#   'lat': 52.5126818,
#   'lon': 13.5780057},
#  560115543: {'type': 'node',
#   'id': 560115543,
#   'lat': 52.5127524,
#   'lon': 13.5785418},
#  560115544: {'type': 'node',
#   'id': 560115544,
#   'lat': 52.5128734,
#   'lon': 13.5790137},
#  560115545: {'type': 'node',
#   'id': 560115545,
#   'lat': 52.5130553,
#   'lon': 13.57951},
#  560115546: {'type': 'node',
#   'id': 560115546,
#   'lat': 52.5132828,
#   'lon': 13.5800271},
#  560115547: {'type': 'node',
#   'id': 560115547,
#   'lat': 52.5135303,
#   'lon': 13.5805411},
#  560115548: {'type': 'node',
#   'id': 560115548,
#   'lat': 52.5141584,
#   'lon': 13.5817957},
#  560115551: {'type': 'node',
#   'id': 560115551,
#   'lat': 52.5166292,
#   'lon': 13.5870514},
#  560115552: {'type': 'node',
#   'id': 560115552,
#   'lat': 52.5164847,
#   'lon': 13.5866619},
#  560115553: {'type': 'node',
#   'id': 560115553,
#   'lat': 52.5166708,
#   'lon': 13.586989},
#  560115554: {'type': 'node',
#   'id': 560115554,
#   'lat': 52.5170326,
#   'lon': 13.5876784},
#  560115555: {'type': 'node',
#   'id': 560115555,
#   'lat': 52.5170759,
#   'lon': 13.5875991},
#  560115557: {'type': 'node',
#   'id': 560115557,
#   'lat': 52.5172989,
#   'lon': 13.5878657},
#  560115558: {'type': 'node',
#   'id': 560115558,
#   'lat': 52.5176061,
#   'lon': 13.5883093},
#  560115559: {'type': 'node',
#   'id': 560115559,
#   'lat': 52.5176423,
#   'lon': 13.5882239},
#  560115560: {'type': 'node',
#   'id': 560115560,
#   'lat': 52.5180185,
#   'lon': 13.5885102},
#  560115565: {'type': 'node',
#   'id': 560115565,
#   'lat': 52.5185805,
#   'lon': 13.5889083},
#  560115566: {'type': 'node',
#   'id': 560115566,
#   'lat': 52.5186008,
#   'lon': 13.5888079},
#  560115567: {'type': 'node',
#   'id': 560115567,
#   'lat': 52.519342,
#   'lon': 13.5889868},
#  560115833: {'type': 'node',
#   'id': 560115833,
#   'lat': 52.5198359,
#   'lon': 13.5889698},
#  560115834: {'type': 'node',
#   'id': 560115834,
#   'lat': 52.5198385,
#   'lon': 13.5891317},
#  560115836: {'type': 'node',
#   'id': 560115836,
#   'lat': 52.5201023,
#   'lon': 13.5891284},
#  560115837: {'type': 'node',
#   'id': 560115837,
#   'lat': 52.5203565,
#   'lon': 13.5889158},
#  560115839: {'type': 'node',
#   'id': 560115839,
#   'lat': 52.520362,
#   'lon': 13.5891072},
#  560115840: {'type': 'node',
#   'id': 560115840,
#   'lat': 52.5211015,
#   'lon': 13.5888253,
#   'tags': {'name': 'Kaulsdorf-Nord',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252601',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252601'}},
#  560117002: {'type': 'node',
#   'id': 560117002,
#   'lat': 52.522542,
#   'lon': 13.5886656},
#  560117003: {'type': 'node',
#   'id': 560117003,
#   'lat': 52.5228675,
#   'lon': 13.5886508},
#  560117005: {'type': 'node',
#   'id': 560117005,
#   'lat': 52.5218086,
#   'lon': 13.5887555,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  560117007: {'type': 'node',
#   'id': 560117007,
#   'lat': 52.5218083,
#   'lon': 13.5889569,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'left'}},
#  560117010: {'type': 'node',
#   'id': 560117010,
#   'lat': 52.5225259,
#   'lon': 13.5888718},
#  560117012: {'type': 'node',
#   'id': 560117012,
#   'lat': 52.5228763,
#   'lon': 13.5888396,
#   'tags': {'railway': 'switch', 'railway:turnout_side': 'right'}},
#  560117017: {'type': 'node',
#   'id': 560117017,
#   'lat': 52.5234965,
#   'lon': 13.5886656},
#  560117020: {'type': 'node',
#   'id': 560117020,
#   'lat': 52.5240359,
#   'lon': 13.5887392},
#  560117021: {'type': 'node',
#   'id': 560117021,
#   'lat': 52.5240108,
#   'lon': 13.5888945},
#  560117027: {'type': 'node',
#   'id': 560117027,
#   'lat': 52.524411,
#   'lon': 13.5888177},
#  560117028: {'type': 'node',
#   'id': 560117028,
#   'lat': 52.5247524,
#   'lon': 13.5889093},
#  560117029: {'type': 'node',
#   'id': 560117029,
#   'lat': 52.5250728,
#   'lon': 13.5890156},
#  560117030: {'type': 'node',
#   'id': 560117030,
#   'lat': 52.5254779,
#   'lon': 13.5891595},
#  560117031: {'type': 'node',
#   'id': 560117031,
#   'lat': 52.5247457,
#   'lon': 13.5889966},
#  560117032: {'type': 'node',
#   'id': 560117032,
#   'lat': 52.5250725,
#   'lon': 13.5890825},
#  560117033: {'type': 'node',
#   'id': 560117033,
#   'lat': 52.5243833,
#   'lon': 13.5889296},
#  560117034: {'type': 'node',
#   'id': 560117034,
#   'lat': 52.5265644,
#   'lon': 13.5895392},
#  560117035: {'type': 'node',
#   'id': 560117035,
#   'lat': 52.5265511,
#   'lon': 13.5896243},
#  560117036: {'type': 'node',
#   'id': 560117036,
#   'lat': 52.5260329,
#   'lon': 13.5894132},
#  560117037: {'type': 'node',
#   'id': 560117037,
#   'lat': 52.5270534,
#   'lon': 13.5897246},
#  560117038: {'type': 'node',
#   'id': 560117038,
#   'lat': 52.5274122,
#   'lon': 13.5898847},
#  560117039: {'type': 'node',
#   'id': 560117039,
#   'lat': 52.5270334,
#   'lon': 13.5898647},
#  560117040: {'type': 'node',
#   'id': 560117040,
#   'lat': 52.5273768,
#   'lon': 13.5900511},
#  560117041: {'type': 'node',
#   'id': 560117041,
#   'lat': 52.5278154,
#   'lon': 13.5900844},
#  560117042: {'type': 'node',
#   'id': 560117042,
#   'lat': 52.5285282,
#   'lon': 13.5904678,
#   'tags': {'name': 'Kienberg (Gärten der Welt)',
#    'public_transport': 'stop_position',
#    'railway': 'stop',
#    'ref:BVG': '252501',
#    'subway': 'yes',
#    'website': 'https://qr.bvg.de/h252501'}},
#  560117045: {'type': 'node',
#   'id': 560117045,
#   'lat': 52.5297185,
#   'lon': 13.5913075},
#  560117049: {'type': 'node',
#   'id': 560117049,
#   'lat': 52.530936,
#   'lon': 13.5917652},
#  560117052: {'type': 'node',
#   'id': 560117052,
#   'lat': 52.53153,
#   'lon': 13.5921152},
#  560117053: {'type': 'node',
#   'id': 560117053,
#   'lat': 52.531742,
#   'lon': 13.5922739},
#  560117054: {'type': 'node',
#   'id': 560117054,
#   'lat': 52.5317177,
#   'lon': 13.5923164},
#  560117056: {'type': 'node',
#   'id': 560117056,
#   'lat': 52.5315177,
#   'lon': 13.5921724},
#  560117057: {'type': 'node',
#   'id': 560117057,
#   'lat': 52.531933,
#   'lon': 13.5924391},
#  560117058: {'type': 'node',
#   'id': 560117058,
#   'lat': 52.532143,
#   'lon': 13.5926517},
#  560117059: {'type': 'node',
#   'id': 560117059,
#   'lat': 52.5319107,
#   'lon': 13.5924865},
#  560139422: {'type': 'node',
#   'id': 560139422,
#   'lat': 52.4951437,
#   'lon': 13.5284318},
#  560139428: {'type': 'node',
#   'id': 560139428,
#   'lat': 52.4977957,
#   'lon': 13.5391287},
#  560139439: {'type': 'node',
#   'id': 560139439,
#   'lat': 52.4987128,
#   'lon': 13.5426518},
#  560139452: {'type': 'node',
#   'id': 560139452,
#   'lat': 52.5003804,
#   'lon': 13.5495965},
#  560139468: {'type': 'node',
#   'id': 560139468,
#   'lat': 52.5016606,
#   'lon': 13.5537618},
#  ...}

# %%
import networkx as nx

def create_route_graph(route_elements, node_elements):
    """
    Creates a graph of routes with stop nodes and edges between consecutive stops.
    Parameters:
    route_elements (list): A list of route elements containing 'members' and 'tags'.
    node_elements (dict): A dictionary of node elements with their IDs as keys.
    Returns:
    nx.Graph: A NetworkX graph object representing the routes and stop nodes.
    """
    # Create a graph object
    G = nx.Graph()

    for route in route_elements:
        stop_nodes = [member for member in route['members'] if 'stop' in member['role']]
        
        # Add nodes to the graph
        for node in stop_nodes:
            ref = node['ref']
            if ref in node_elements:
                node_data = node_elements[ref]
                name = node_data['tags'].get('name', str(ref))
                colour = route['tags'].get('colour', '#808080')  # Default gray color if no color is defined
                
                G.add_node(ref, pos=(node_data['lon'], node_data['lat']), name=name, colour=colour)
        
        # Add edges between consecutive stop nodes
        for i in range(len(stop_nodes) - 1):
            G.add_edge(stop_nodes[i]['ref'], stop_nodes[i + 1]['ref'])
    
    return G

# %%
import matplotlib.pyplot as plt

def visualize_graph(G, title):
    """
    Visualizes the graph with nodes and edges.
    Parameters:
    G (nx.Graph): A NetworkX graph object representing the routes and stop nodes.
    Returns:
    None: Displays a plot of the graph.
    """
    # Set the plot size
    plt.figure(figsize=(15, 8))  # Adjust the width and height as needed

    # Draw the graph with nodes and edges
    pos = nx.get_node_attributes(G, 'pos')
    node_labels = nx.get_node_attributes(G, 'name')
    node_colours = list(nx.get_node_attributes(G, 'colour').values())
    nx.draw(G, pos, with_labels=True, labels=node_labels, node_size=100, node_color=node_colours, font_size=8)
    nx.draw_networkx_edges(G, pos, edge_color='gray', alpha=0.7)
    plt.title(title)
    plt.show()

# Create the graph for the Hamburg subway system
subway_berlin_G = create_route_graph(route_elements, node_elements)

# Visualize the graph with a title
visualize_graph(subway_berlin_G, 'Berlin Subway System')

# %%
import folium

def visualize_graph_on_folium(G, title, map_center=(52.5200, 13.4050), zoom_start=12):
    """
    Visualizes a NetworkX graph on an interactive Folium map.
    Parameters:
    G (nx.Graph): A NetworkX graph object representing the subway network.
    title (str): Title for the map.
    map_center (tuple): Latitude and longitude for centering the map.
    zoom_start (int): Initial zoom level for the map.
    Returns:
    folium.Map: A Folium map object with the graph plotted.
    """
    # Create a Folium map centered on the specified coordinates
    subway_map = folium.Map(location=map_center, zoom_start=zoom_start)
    
    # Get positions and attributes from the graph
    pos = nx.get_node_attributes(G, 'pos')  # Node positions
    node_colours = nx.get_node_attributes(G, 'colour')  # Node colors
    node_names = nx.get_node_attributes(G, 'name')  # Node names
    
    # Add nodes as markers
    for node, coords in pos.items():
        name = node_names.get(node, "Unnamed Station")
        colour = node_colours.get(node, "#000000")  # Default black if no color specified
        folium.CircleMarker(
            location=(coords[1], coords[0]),  # Folium uses (lat, lon)
            radius=5,
            color=colour,
            fill=True,
            fill_opacity=0.7,
            popup=folium.Popup(name, max_width=300)
        ).add_to(subway_map)
    
    # Add edges as polylines
    for edge in G.edges():
        coord1 = pos[edge[0]]
        coord2 = pos[edge[1]]
        colour = node_colours.get(edge[0], "gray")  # Use the color of the first node in the edge
        folium.PolyLine(
            locations=[(coord1[1], coord1[0]), (coord2[1], coord2[0])],  # Folium uses (lat, lon)
            color=colour,
            weight=2,
            opacity=0.6
        ).add_to(subway_map)
    
    # Add a title to the map (via a custom HTML overlay)
    title_html = f'''
         <h3 align="center" style="font-size:16px"><b>{title}</b></h3>
         '''
    subway_map.get_root().html.add_child(folium.Element(title_html))
    
    return subway_map

# Create the Folium map
berlin_subway_map = visualize_graph_on_folium(subway_berlin_G, "Berlin Subway Network")

# Save the map to an HTML file
berlin_subway_map.save("berlin_subway_network.html")
print("Map saved as 'berlin_subway_network.html'!")

berlin_subway_map
# Out:
# Map saved as 'berlin_subway_network.html'!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_226e676becc417f2a1c2cb221a3988ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#          &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Berlin Subway Network&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_226e676becc417f2a1c2cb221a3988ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_226e676becc417f2a1c2cb221a3988ee = L.map(
#                 &quot;map_226e676becc417f2a1c2cb221a3988ee&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a6a41fda90d436224239f968fcaf041 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a6a41fda90d436224239f968fcaf041.addTo(map_226e676becc417f2a1c2cb221a3988ee);
#
#
#             var circle_marker_ac9c279fe572947dedc35a4a3eacf413 = L.circleMarker(
#                 [52.5251423, 13.3700843],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7E5330&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7E5330&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_226e676becc417f2a1c2cb221a3988ee);
#
#
#         var popup_905d0376c3b669d5397df3791d66c83e = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_098b888f97095b5d10c39d934de99b30 = $(`&lt;div id=&quot;html_098b888f97095b5d10c39d934de99b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hauptbahnhof&lt;/div&gt;`)[0];
#                 popup_905d0376c3b669d5397df3791d66c83e.setContent(html_098b888f97095b5d10c39d934de99b30);
#
#
#
#         circle_marker_ac9c279fe572947dedc35a4a3eacf413.bindPopup(popup_905d0376c3b669d5397df3791d66c83e)
#         ;
#
#
#
#
#             var circle_marker_65d84ebe5282ef5a0d6a018725f4135f = L.circleMarker(
#                 [52.5201499, 13.3728265],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7E5330&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7E5330&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_226e676becc417f2a1c2cb221a3988ee);
#
#
#         var popup_5ee724d452cc137743acbbc9f308f8e9 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6451435bfeb76dbc55946ab4c01a0ba5 = $(`&lt;div id=&quot;html_6451435bfeb76dbc55946ab4c01a0ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bundestag&lt;/div&gt;`)[0];
#                 popup_5ee724d452cc137743acbbc9f308f8e9.setContent(html_6451435bfeb76dbc55946ab4c01a0ba5);
#
#
#
#         circle_marker_65d84ebe5282ef5a0d6a018725f4135f.bindPopup(popup_5ee724d452cc137743acbbc9f308f8e9)
#         ;
#
#
#
#
#             var circle_marker_396e477fbbb2a72001879d8114126fe6 = L.circleMarker(
#                 [52.5165428, 13.3811753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7E5330&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7E5330&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_226e676becc417f2a1c2cb221a3988ee);
#
#
#         var popup_c5d48cb4cd4985bc0d830eec50912338 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_0414280314c491694f4968f71190f5d7 = $(`&lt;div id=&quot;html_0414280314c491694f4968f71190f5d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brandenburger Tor&lt;/div&gt;`)[0];
#                 popup_c5d48cb4cd4985bc0d830eec50912338.setContent(html_0414280314c491694f4968f71190f5d7);
#
#
#
#         circle_marker_396e477fbbb2a72001879d8114126fe6.bindPopup(popup_c5d48cb4cd4985bc0d830eec50912338)
#         ;
#
#
#
#
#             var circle_marker_18343e846ff75fc6f5c20ff5280de9ad = L.circleMarker(
#                 [52.5169314, 13.3898289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&
